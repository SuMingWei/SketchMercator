# %%
import pickle
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import random
import json
import os
import re
import seaborn as sns
import math
import sys
import copy
from matplotlib.ticker import FormatStrFormatter

# %%
## parameters

caida = ["caida-500w", "caida-250w", "caida-125w", "caida-50w"]
zipf2 = ["zipf2-250w", "zipf2-125w", "zipf2-50w"]
zipf1 = ["zipf1-250w", "zipf1-125w", "zipf1-50w"]


lens = [
        # ["5", "5"],
        ["6", "4"],
        # ["7", "3"],
        # ["8", "2"],
        ]

pcap_file = []
    
# # single dataset
pcap_file.append("caida-500w_10_.pcap")
pcap_file.append("caida-250w_10_.pcap")
pcap_file.append("caida-125w_10_.pcap")
pcap_file.append("caida-50w_10_.pcap")
pcap_file.append("zipf2-250w_10_.pcap") 
pcap_file.append("zipf2-125w_10_.pcap") 
pcap_file.append("zipf2-50w_10_.pcap") 
pcap_file.append("zipf1-250w_10_.pcap") 
pcap_file.append("zipf1-125w_10_.pcap") 
pcap_file.append("zipf1-50w_10_.pcap") 

### caida + zipf2 [10:22]
for a in caida:
    for b in zipf2:
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
### zipf2 + caida [22:34]
for a in zipf2:
    for b in caida:
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
### caida + zipf1 [34:46]
for a in caida:
    for b in zipf1:
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
### zipf1 + caida [46:58]
for a in zipf1:
    for b in caida:
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
### zipf2 + zipf1 [58:67]
for a in zipf2:
    for b in zipf1:
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
### zipf1 + zipf2 [67:76]
for a in zipf1:
    for b in zipf2:
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
### caida + caida [76:88]
for a in caida:
    for b in caida:
        if a == b:
            continue
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
### zipf2 + zipf2 [88:94]
for a in zipf2:
    for b in zipf2:
        if a == b:
            continue
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
### zipf1 + zipf1 [94:100]
for a in zipf1:
    for b in zipf1:
        if a == b:
            continue
        for l in lens:
            pcap_file.append(f'{a}_{l[0]}_{b}_{l[1]}.pcap')
            
print(pcap_file)    
print(f'Total Pcap File Number: {len(pcap_file)}')
# widths = [2048, 4096, 8192, 16384, 32768, 65536, 131072]
widths = [4096]
# widths = [1024]
# Out:
# ['caida-500w_10_.pcap', 'caida-250w_10_.pcap', 'caida-125w_10_.pcap', 'caida-50w_10_.pcap', 'zipf2-250w_10_.pcap', 'zipf2-125w_10_.pcap', 'zipf2-50w_10_.pcap', 'zipf1-250w_10_.pcap', 'zipf1-125w_10_.pcap', 'zipf1-50w_10_.pcap', 'caida-500w_6_zipf2-250w_4.pcap', 'caida-500w_6_zipf2-125w_4.pcap', 'caida-500w_6_zipf2-50w_4.pcap', 'caida-250w_6_zipf2-250w_4.pcap', 'caida-250w_6_zipf2-125w_4.pcap', 'caida-250w_6_zipf2-50w_4.pcap', 'caida-125w_6_zipf2-250w_4.pcap', 'caida-125w_6_zipf2-125w_4.pcap', 'caida-125w_6_zipf2-50w_4.pcap', 'caida-50w_6_zipf2-250w_4.pcap', 'caida-50w_6_zipf2-125w_4.pcap', 'caida-50w_6_zipf2-50w_4.pcap', 'zipf2-250w_6_caida-500w_4.pcap', 'zipf2-250w_6_caida-250w_4.pcap', 'zipf2-250w_6_caida-125w_4.pcap', 'zipf2-250w_6_caida-50w_4.pcap', 'zipf2-125w_6_caida-500w_4.pcap', 'zipf2-125w_6_caida-250w_4.pcap', 'zipf2-125w_6_caida-125w_4.pcap', 'zipf2-125w_6_caida-50w_4.pcap', 'zipf2-50w_6_caida-500w_4.pcap', 'zipf2-50w_6_caida-250w_4.pcap', 'zipf2-50w_6_caida-125w_4.pcap', 'zipf2-50w_6_caida-50w_4.pcap', 'caida-500w_6_zipf1-250w_4.pcap', 'caida-500w_6_zipf1-125w_4.pcap', 'caida-500w_6_zipf1-50w_4.pcap', 'caida-250w_6_zipf1-250w_4.pcap', 'caida-250w_6_zipf1-125w_4.pcap', 'caida-250w_6_zipf1-50w_4.pcap', 'caida-125w_6_zipf1-250w_4.pcap', 'caida-125w_6_zipf1-125w_4.pcap', 'caida-125w_6_zipf1-50w_4.pcap', 'caida-50w_6_zipf1-250w_4.pcap', 'caida-50w_6_zipf1-125w_4.pcap', 'caida-50w_6_zipf1-50w_4.pcap', 'zipf1-250w_6_caida-500w_4.pcap', 'zipf1-250w_6_caida-250w_4.pcap', 'zipf1-250w_6_caida-125w_4.pcap', 'zipf1-250w_6_caida-50w_4.pcap', 'zipf1-125w_6_caida-500w_4.pcap', 'zipf1-125w_6_caida-250w_4.pcap', 'zipf1-125w_6_caida-125w_4.pcap', 'zipf1-125w_6_caida-50w_4.pcap', 'zipf1-50w_6_caida-500w_4.pcap', 'zipf1-50w_6_caida-250w_4.pcap', 'zipf1-50w_6_caida-125w_4.pcap', 'zipf1-50w_6_caida-50w_4.pcap', 'zipf2-250w_6_zipf1-250w_4.pcap', 'zipf2-250w_6_zipf1-125w_4.pcap', 'zipf2-250w_6_zipf1-50w_4.pcap', 'zipf2-125w_6_zipf1-250w_4.pcap', 'zipf2-125w_6_zipf1-125w_4.pcap', 'zipf2-125w_6_zipf1-50w_4.pcap', 'zipf2-50w_6_zipf1-250w_4.pcap', 'zipf2-50w_6_zipf1-125w_4.pcap', 'zipf2-50w_6_zipf1-50w_4.pcap', 'zipf1-250w_6_zipf2-250w_4.pcap', 'zipf1-250w_6_zipf2-125w_4.pcap', 'zipf1-250w_6_zipf2-50w_4.pcap', 'zipf1-125w_6_zipf2-250w_4.pcap', 'zipf1-125w_6_zipf2-125w_4.pcap', 'zipf1-125w_6_zipf2-50w_4.pcap', 'zipf1-50w_6_zipf2-250w_4.pcap', 'zipf1-50w_6_zipf2-125w_4.pcap', 'zipf1-50w_6_zipf2-50w_4.pcap', 'caida-500w_6_caida-250w_4.pcap', 'caida-500w_6_caida-125w_4.pcap', 'caida-500w_6_caida-50w_4.pcap', 'caida-250w_6_caida-500w_4.pcap', 'caida-250w_6_caida-125w_4.pcap', 'caida-250w_6_caida-50w_4.pcap', 'caida-125w_6_caida-500w_4.pcap', 'caida-125w_6_caida-250w_4.pcap', 'caida-125w_6_caida-50w_4.pcap', 'caida-50w_6_caida-500w_4.pcap', 'caida-50w_6_caida-250w_4.pcap', 'caida-50w_6_caida-125w_4.pcap', 'zipf2-250w_6_zipf2-125w_4.pcap', 'zipf2-250w_6_zipf2-50w_4.pcap', 'zipf2-125w_6_zipf2-250w_4.pcap', 'zipf2-125w_6_zipf2-50w_4.pcap', 'zipf2-50w_6_zipf2-250w_4.pcap', 'zipf2-50w_6_zipf2-125w_4.pcap', 'zipf1-250w_6_zipf1-125w_4.pcap', 'zipf1-250w_6_zipf1-50w_4.pcap', 'zipf1-125w_6_zipf1-250w_4.pcap', 'zipf1-125w_6_zipf1-50w_4.pcap', 'zipf1-50w_6_zipf1-250w_4.pcap', 'zipf1-50w_6_zipf1-125w_4.pcap']
# Total Pcap File Number: 100

# %%
def read_single_window_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
              epochs=['10'], dataset='caida-125w_10_.pcap', window_size=200, k=5000):
    res = []
    for epoch in epochs:
        
        path = f"SketchQuery/{algo}/{dataset[:-5]}/"\
                f"{flowkey}/row_{row}_width_{width}_level_{level}_epoch_{epoch}_count_{count}_seed_{seed}/"
        
        for dir in sorted(os.listdir(path)):
            p = os.path.join(path, dir)
            if os.path.isdir(p): 
                window_dir = "window_" + str(window_size)
                dynamic_full_path = os.path.join(path, dir, window_dir, f"top{k}/single_window_randk_summation")
                
                for file in sorted(os.listdir(dynamic_full_path)):  
                    fsd_file = os.path.join(dynamic_full_path, file)
                    fsd = {}
                    with open(fsd_file, 'r') as f:
                        for line in f:
                            if int(line.strip().split()[0]) == 0:
                                continue
                            fsd[int(line.strip().split()[0])] = int(line.strip().split()[1])
                            
                    res.append(fsd)
            
    return res

# read_fsd_data()

# %%
def read_offline_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
              epochs=['10'], dataset='caida-125w_10_.pcap', window_size=200,k=5000):
    res = []
    for epoch in epochs:
        
        path = f"SketchQueryOffline/{algo}/{dataset[:-5]}/"\
                f"{flowkey}/row_{row}_width_{width}_level_{level}_epoch_{epoch}_count_{count}_seed_{seed}/"
        
        for dir in sorted(os.listdir(path)):
            p = os.path.join(path, dir)
            if os.path.isdir(p): 
                window_dir = "window_" + str(window_size)
                dynamic_full_path = os.path.join(path, dir, window_dir, f"top{k}/single_window_randk_summation")
                
                for file in sorted(os.listdir(dynamic_full_path)):  
                    fsd_file = os.path.join(dynamic_full_path, file)
                    fsd = {}
                    with open(fsd_file, 'r') as f:
                        for line in f:
                            if int(line.strip().split()[0]) == 0:
                                continue
                            fsd[int(line.strip().split()[0])] = int(line.strip().split()[1])
                            
                    res.append(fsd)
            
    return res

# read_fsd_data()

# %%
def read_single_window_gt_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
              epochs=['10'], dataset='caida-125w_10_.pcap', window_size=200):
    res = []
    for epoch in epochs:
        
        path = f"SketchQueryOffline/{algo}/{dataset[:-5]}/"\
                f"{flowkey}/row_{row}_width_{width}_level_{level}_epoch_{epoch}_count_{count}_seed_{seed}/"
        
        for dir in sorted(os.listdir(path)):
            p = os.path.join(path, dir)
            if os.path.isdir(p): 
                window_dir = "window_" + str(window_size)
                dynamic_full_path = os.path.join(path, dir, window_dir, "gt/single_window_randk_gt_summation")
                
                for file in sorted(os.listdir(dynamic_full_path)):  
                    fsd_file = os.path.join(dynamic_full_path, file)
                    fsd = {}
                    with open(fsd_file, 'r') as f:
                        for line in f:
                            if int(line.strip().split()[0]) == 0:
                                continue
                            fsd[int(line.strip().split()[0])] = int(line.strip().split()[1])
                            
                    res.append(fsd)
            
    return res

# %%
def prepare_testing_gt_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
              epochs=['10'], datasets=['caida-125w_10_.pcap'], window_size=200):
    
    profiler_fsd = {}
    for d in datasets:
        profiler_fsd[d[:-9]] = []
    
    # res = {}
    for epoch in epochs:
        for pf in profiler_fsd.keys():
            path = f"SketchQuery/{algo}/{pf}_10_/"\
                    f"{flowkey}/row_{row}_width_{width}_level_{level}_epoch_{epoch}_count_{count}_seed_{seed}/"
            
            for dir in sorted(os.listdir(path)):
                p = os.path.join(path, dir)
                if os.path.isdir(p): 
                    window_dir = "window_" + str(window_size)
                    dynamic_full_path = os.path.join(path, dir, window_dir, "gt/single_window_randk_gt_summation")
                    
                    for file in sorted(os.listdir(dynamic_full_path)):  
                        fsd_file = os.path.join(dynamic_full_path, file)
                        fsd = {}
                        with open(fsd_file, 'r') as f:
                            for line in f:
                                if int(line.strip().split()[0]) == 0:
                                    continue
                                fsd[int(line.strip().split()[0])] = int(line.strip().split()[1])
                                
                        profiler_fsd[pf].append(fsd)
                
    return profiler_fsd

# read_fsd_data()

# %%
def prepare_testing_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
              epochs=['10'], datasets=['caida-125w_10_.pcap'], window_size=200, k=5000):
    
    profiler_fsd = {}
    
    for d in datasets:
        profiler_fsd[d[:-9]] = []
    
    # res = {}
    for epoch in epochs:
        for pf in profiler_fsd.keys():
            path = f"SketchQuery/{algo}/{pf}_10_/"\
                    f"{flowkey}/row_{row}_width_{width}_level_{level}_epoch_{epoch}_count_{count}_seed_{seed}/"
            
            for dir in sorted(os.listdir(path)):
                p = os.path.join(path, dir)
                if os.path.isdir(p): 
                    window_dir = "window_" + str(window_size)
                    dynamic_full_path = os.path.join(path, dir, window_dir, f"top{k}/single_window_randk_summation")
                    
                    for file in sorted(os.listdir(dynamic_full_path)):  
                        fsd_file = os.path.join(dynamic_full_path, file)
                        fsd = {}
                        with open(fsd_file, 'r') as f:
                            for line in f:
                                if int(line.strip().split()[0]) == 0:
                                    continue
                                fsd[int(line.strip().split()[0])] = int(line.strip().split()[1])
                                
                        profiler_fsd[pf].append(fsd)
                
    return profiler_fsd

# read_fsd_data()

# %%
def prepare_profiler_offline_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
              epochs=['10'], datasets=['caida125w_10_.pcap'], window_size=200,k=5000):
    
    profiler_fsd = {}
    
    for d in datasets:
        profiler_fsd[d[:-9]] = []
    
    # res = {}
    for epoch in epochs:
        for pf in profiler_fsd.keys():
            path = f"SketchQueryOffline/{algo}/{pf}_10_/"\
                    f"{flowkey}/row_{row}_width_{width}_level_{level}_epoch_{epoch}_count_{count}_seed_{seed}/"
            
            for dir in sorted(os.listdir(path)):
                p = os.path.join(path, dir)
                if os.path.isdir(p): 
                    window_dir = "window_" + str(window_size)
                    dynamic_full_path = os.path.join(path, dir, window_dir, f"top{k}/single_window_randk_summation")
                    
                    for file in sorted(os.listdir(dynamic_full_path)):  
                        fsd_file = os.path.join(dynamic_full_path, file)
                        fsd = {}
                        with open(fsd_file, 'r') as f:
                            for line in f:
                                if int(line.strip().split()[0]) == 0:
                                    continue
                                fsd[int(line.strip().split()[0])] = int(line.strip().split()[1])
                                
                        profiler_fsd[pf].append(fsd)
                
    return profiler_fsd

# read_fsd_data()

# %%
def prepare_profiler_offline_gt_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
              epochs=['10'], datasets=['caida-125w_10_.pcap'], window_size=200,k=5000):
    
    profiler_fsd = {}
    
    for d in datasets:
        profiler_fsd[d[:-9]] = []
    
    # res = {}
    for epoch in epochs:
        for pf in profiler_fsd.keys():
            path = f"SketchQueryOffline/{algo}/{pf}_10_/"\
                    f"{flowkey}/row_{row}_width_{width}_level_{level}_epoch_{epoch}_count_{count}_seed_{seed}/"
            
            for dir in sorted(os.listdir(path)):
                p = os.path.join(path, dir)
                if os.path.isdir(p): 
                    window_dir = "window_" + str(window_size)
                    dynamic_full_path = os.path.join(path, dir, window_dir, f"gt/single_window_randk_gt_summation")
                    
                    for file in sorted(os.listdir(dynamic_full_path)):  
                        fsd_file = os.path.join(dynamic_full_path, file)
                        fsd = {}
                        with open(fsd_file, 'r') as f:
                            for line in f:
                                if int(line.strip().split()[0]) == 0:
                                    continue
                                fsd[int(line.strip().split()[0])] = int(line.strip().split()[1])
                                
                        profiler_fsd[pf].append(fsd)
                
    return profiler_fsd

# read_fsd_data()

# %%
def calculate_mrd(fsd1, fsd2):
    MRD_nom = 0
    MRD_denom = 0
    for i in range(1, max(fsd1.keys())+1):
        if i in fsd1.keys():
            true = fsd1[i]
        else:
            true = 0
            
        if i in fsd2.keys():
            est = fsd2[i]
        else:
            est = 0
            
        MRD_nom += abs(true - est)
        MRD_denom += float(true + est)/2
    MRD = MRD_nom/MRD_denom
    
    return MRD

# %%
def get_avg_fsd(fsd_list):
    avg_fsd = {}
    
    all_keys = set().union(*[d.keys() for d in fsd_list])
    for key in all_keys:
        avg_fsd[key] = 0
        
    for fsd in fsd_list:
        for key, val in fsd.items():
            avg_fsd[key] += val
            
    avg_fsd = {key: int(val/len(fsd_list)) for key, val in avg_fsd.items()}
    
    sorted_fsd = dict(sorted(list(avg_fsd.items())))
    
    return sorted_fsd

# %%
def get_sum_fsd(fsd_list):
    avg_fsd = {}
    
    all_keys = set().union(*[d.keys() for d in fsd_list])
    for key in all_keys:
        avg_fsd[key] = 0
        
    for fsd in fsd_list:
        for key, val in fsd.items():
            avg_fsd[key] += val
            
    # avg_fsd = {key: int(val/len(fsd_list)) for key, val in avg_fsd.items()}
    
    sorted_fsd = dict(sorted(list(avg_fsd.items())))
    
    return sorted_fsd

# %%
def get_fsd_dict(dataset):
    fsd = {}
    with open(dataset, "r") as file:
        for line in file:
            items = line.strip().split(" ")
            fsd[int(items[0])] = int(items[1])
    
    sorted_fsd = dict(sorted(list(fsd.items())))
    
    return sorted_fsd

# %%
def normalize_fsd(fsd):
    fn = sum(list(fsd.values()))
    
    return {key: (val/fn) for key,val in fsd.items()}

# %% [markdown]
# ---

# %%
def plot_impact_of_mem_cdf(dataset, widths, plot_type, s, fig_size=(6,6),output='Thesis'):
    
    fs = []
    prob = []
    cdfs = []
    labels = []
    all_fsd = {}
    
    # # Prepare origin fsd
    # pcap_folder = "/home/ming/SketchMercator/pattern_detection/traffic_generator/fs_dist_new/"
    # file_path = pcap_folder + dataset[:-9] + '.txt'
    # all_fsd['GT'] = get_fsd_dict(file_path)
    
    # # Prepare origin fsd ## width=4096
    fsds = read_single_window_gt_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
                                                epochs=['10'], dataset=dataset, window_size=200)
    all_fsd['$FSD_d$'] = get_avg_fsd(fsds)
            
    if plot_type == "Dirty":
        for w in widths:
            fsds = read_offline_fsd_data(algo='cm', row=3, width=w, level=1, seed=1, count=1, flowkey='srcIP', 
                                                        epochs=['10'], dataset=dataset, window_size=200, k=5000)
            all_fsd[f'$FSD\'_d$-{int(w*16/1024)}KB'] = get_avg_fsd(fsds)
    
    for w in widths:
        fsds = read_single_window_fsd_data(algo='cm', row=3, width=w, level=1, seed=1, count=1, flowkey='srcIP', 
                                                    epochs=['10'], dataset=dataset, window_size=200, k=5000)
        all_fsd[f'$FSD_s$-{int(w*16/1024)}KB'] = get_avg_fsd(fsds)
        
    # fsds = read_single_window_gt_fsd_data(algo='cm', row=3, width=4096, level=1, seed=1, count=1, flowkey='srcIP', 
    #                                             epochs=['10'], dataset=dataset, window_size=200)
    # all_fsd[f'Mem=INF'] = get_sum_fsd(fsds)
    
    linestyles = ['-.', '--', ':', '-']
    from matplotlib import cm
    greens = cm.Greens(np.linspace(0.4, 0.8, 4))
    colors_g = np.concatenate([greens])
    blues = cm.Blues(np.linspace(0.4, 0.8, 4))
    colors_b = np.concatenate([blues])
    oranges = cm.Oranges(np.linspace(0.4, 0.8, 4))
    colors_o = np.concatenate([oranges])
    
    for name, fsd in all_fsd.items(): 
        flow_size = list(fsd.keys())
        frequency = list(fsd.values()) 

        total_flows = sum(frequency)
        probabilities = [freq / total_flows for freq in frequency]
        
        cdf = np.cumsum(probabilities)
        
        
        fs.append(flow_size)
        prob.append(probabilities)
        cdfs.append(cdf)
        labels.append(name)
    
    plt.figure(figsize=fig_size)
    # Plot CDF
    for i in range(len(fs)):
        if labels[i] =='$FSD_d$':
            plt.plot(fs[i], cdfs[i], label = labels[i], linewidth=3, linestyle="-")
        else:
            if plot_type == "GT":
                plt.plot(fs[i], cdfs[i], label = labels[i], linewidth=3, linestyle=linestyles[(i-1)%len(widths)], color=colors_g[(i-1)%len(widths)], alpha=0.8)
            elif plot_type == "Dirty":
                if labels[i].split("-")[0] == "$FSD\'_d$":
                    plt.plot(fs[i], cdfs[i], label = labels[i], linewidth=3, linestyle=linestyles[(i-1)%len(widths)], color=colors_o[(i-1)%len(widths)], alpha=0.8)
                elif labels[i].split("-")[0] == "$FSD_s$":
                    plt.plot(fs[i], cdfs[i], label = labels[i], linewidth=3, linestyle=linestyles[(i-1)%len(widths)], color=colors_g[(i-1)%len(widths)], alpha=0.8)
            
    # plt.title(f'Impact of Memory ({dataset[:-9]})', fontsize=20)
    plt.xlabel('Flow size', fontsize=s[0])
    plt.ylabel('CDFs', fontsize=s[0])
    if fig_size == (8,6):
        if plot_type == "GT":
            plt.legend(loc="lower right", ncol=1, fontsize=s[1], handlelength=0.9, labelspacing=0.3)
        else:
            plt.legend(loc="lower right", ncol=2, fontsize=s[1], handlelength=0.9, columnspacing=0.5, labelspacing=0.3)
    else:
        plt.legend(loc="lower right", ncol=1, fontsize=s[1], handlelength=0.9, labelspacing=0.3)
    
    plt.xscale('log')  # Set x-axis scale to logarithmic
    plt.ylim([-0.05,1.05])
    # plt.xlim([-10,100000])
    # plt.xticks([1, 10, 100, 1000, 10000, 100000], size=s[0])  # Set specific tick positions
    plt.xlim([-10,10000])
    plt.xticks([1, 10, 100, 1000, 10000], size=s[1])  # Set specific tick positions
    plt.yticks(size=s[1])
    plt.grid(True)
    plt.gca().spines[['top', 'right']].set_visible(False)
    
    
    plt.tight_layout()
    if output != '':
        if output == 'Slide':
            if plot_type == 'GT':
                plt.savefig(f'../../{output}/PI-FSD/mem_true_{dataset.split("-")[0]}.png')
            else:
                plt.savefig(f'../../{output}/PI-FSD/mem_fake_{dataset.split("-")[0]}.png')
        else:
            if plot_type == 'GT':
                plt.savefig(f'../../{output}/PI-FSD/mem_true_{dataset.split("-")[0]}.pdf')
            else:
                plt.savefig(f'../../{output}/PI-FSD/mem_fake_{dataset.split("-")[0]}.pdf')
    plt.show()

# %%
# # slides
plot_impact_of_mem_cdf(dataset=pcap_file[4], widths=[2048, 4096, 8192, 16384], plot_type="GT", s=[36,30], fig_size=(8,6), output='Slide')
plot_impact_of_mem_cdf(dataset=pcap_file[4], widths=[2048, 4096, 8192, 16384], plot_type="Dirty", s=[36,22], fig_size=(8,6), output='Slide')


# # conference
plot_impact_of_mem_cdf(dataset=pcap_file[4], widths=[2048, 4096, 8192, 16384], plot_type="GT", s=[28,22], output='Conference')
plot_impact_of_mem_cdf(dataset=pcap_file[4], widths=[2048, 4096, 8192, 16384], plot_type="Dirty", s=[28,22], output='Conference')

# # thesis
plot_impact_of_mem_cdf(dataset=pcap_file[4], widths=[2048, 4096, 8192, 16384], plot_type="GT", s=[24,22], output='Thesis')
plot_impact_of_mem_cdf(dataset=pcap_file[4], widths=[2048, 4096, 8192, 16384], plot_type="Dirty", s=[24,22], output='Thesis')
# Out:
# /tmp/ipykernel_36582/2969232626.py:87: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim([-10,10000])
# /tmp/ipykernel_36582/2969232626.py:87: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim([-10,10000])
# /tmp/ipykernel_36582/2969232626.py:87: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim([-10,10000])
# /tmp/ipykernel_36582/2969232626.py:87: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim([-10,10000])

# %% [markdown]
# ---

# %%
def plot_impact_of_volumn_cdf(datasets, width, k, plot_type, s, fig_size=(6,6), output='Thesis'):
    
    mapping = {'500w':'5000k', '250w':'2500k', '125w':'1250k', '50w':'500k'}
    fs = []
    prob = []
    cdfs = []
    labels = []
    all_fsd = {}
    
    # Prepare origin fsd
    pcap_folder = "/home/ming/SketchMercator/pattern_detection/traffic_generator/fs_dist_new/"
    # colors = {'caida':'tab:blue', 'zipf2':'tab:orange', 'zipf1':'tab:green'}
    
    if plot_type == "GT":
        for d in datasets:
            fsds = read_single_window_gt_fsd_data(algo='cm', row=3, width=width, level=1, seed=1, count=1, flowkey='srcIP', 
                                                    epochs=['10'], dataset=d, window_size=200)
            all_fsd[f'$FSD_d$-{d[:-9].split("-")[1]}'] = get_avg_fsd(fsds)
            # file_path = pcap_folder + d[:-9] + '.txt'
            # all_fsd[f'GT-{d[:-9]}'] = get_fsd_dict(file_path)  
    else:
        for d in datasets:
            fsds = read_offline_fsd_data(algo='cm', row=3, width=width, level=1, seed=1, count=1, flowkey='srcIP', 
                                                        epochs=['10'], dataset=d, window_size=200,k=k)
            all_fsd[f'$FSD\'_d$-{d[:-9].split("-")[1]}'] = get_avg_fsd(fsds)
            # all_fsd[d[:-9]] = get_sum_fsd(fsds)
        
    for d in datasets:
        fsds = read_single_window_fsd_data(algo='cm', row=3, width=width, level=1, seed=1, count=1, flowkey='srcIP', 
                                                    epochs=['10'], dataset=d, window_size=200,k=k)
        all_fsd[f'$FSD_s$-{d[:-9].split("-")[1]}'] = get_avg_fsd(fsds)
    
    for name, fsd in all_fsd.items(): 
        flow_size = list(fsd.keys())
        frequency = list(fsd.values()) 

        total_flows = sum(frequency)
        probabilities = [freq / total_flows for freq in frequency]
        
        cdf = np.cumsum(probabilities)
        
        fs.append(flow_size)
        prob.append(probabilities)
        cdfs.append(cdf)
        labels.append(name)
    
    linestyles = ['-.', '--', ':', '-']
    from matplotlib import cm
    if len(datasets) == 3:
        blues = cm.Blues(np.linspace(0.5, 0.8, 3))
        oranges = cm.Oranges(np.linspace(0.5, 0.8, 3))
        greens = cm.Greens(np.linspace(0.5, 0.8, 3))
    else:
        blues = cm.Blues(np.linspace(0.4, 0.8, 4))
        oranges = cm.Oranges(np.linspace(0.4, 0.8, 4))
        greens = cm.Greens(np.linspace(0.4, 0.8, 4))
    
    colors = np.concatenate([blues, greens])
    if plot_type == "Dirty":
        colors = np.concatenate([oranges, greens])
    
    print(len(colors))

    
    plt.figure(figsize=fig_size)
    # Plot CDF
    # plt.title(f'Impact of Data Volumn ({datasets[0].split("-")[0]})', fontsize=20)
    # plt.title(f'CDF of GT')
    for i in range(len(fs)):
        ls = linestyles[4-len(datasets):]
        plt.plot(fs[i], cdfs[i], label = f'{labels[i].split("-")[0]}-{mapping[labels[i].split("-")[1]]}', linewidth=3, color=colors[i], linestyle=ls[i%len(datasets)])
        # if labels[i].split("-")[-1] == "GT":
        #     plt.plot(fs[i], cdfs[i], label = labels[i], linewidth=3, color=colors[i], linestyle=linestyles[i%4])
        # else:
        #     plt.plot(fs[i], cdfs[i], label = labels[i], linewidth=3, color=colors[i], linestyle=linestyles[i%4])
    plt.xlabel('Flow size', fontsize=s[0])
    plt.ylabel('CDFs', fontsize=s[0])
    if fig_size == (8,6):
        if plot_type == "GT":
            plt.legend(loc="lower right", ncol=1, fontsize=s[1], handlelength=0.9, labelspacing=0.3)
        else:
            plt.legend(loc="lower right", ncol=2, fontsize=s[1], handlelength=0.9, columnspacing=0.5, labelspacing=0.3)
    else:
        plt.legend(loc="lower right", ncol=1, fontsize=s[1], handlelength=0.9, labelspacing=0.3)
    
    plt.xscale('log')  # Set x-axis scale to logarithmic
    # plt.xlim(0, 100000)
    # plt.xticks([1, 10, 100, 1000, 10000, 100000], size=s[0])  # Set specific tick positions
    plt.xlim(0, 10000)
    plt.xticks([1, 10, 100, 1000, 10000], size=s[1])  # Set specific tick positions
    plt.yticks(size=s[1])
    plt.grid(True)
    plt.gca().spines[['top', 'right']].set_visible(False)
    
    
    plt.tight_layout()
    if output != '':
        if output == 'Slide':
            if plot_type == 'GT':
                plt.savefig(f'../../{output}/PI-FSD/volume_true_{datasets[0].split("-")[0]}.png')
            else:
                plt.savefig(f'../../{output}/PI-FSD/volume_fake_{datasets[0].split("-")[0]}.png')
        else:
            if plot_type == 'GT':
                plt.savefig(f'../../{output}/PI-FSD/volume_true_{datasets[0].split("-")[0]}.pdf')
            else:
                plt.savefig(f'../../{output}/PI-FSD/volume_fake_{datasets[0].split("-")[0]}.pdf')
    plt.show()

# %%
# # slide
plot_impact_of_volumn_cdf(datasets=pcap_file[4:7],width=4096, k=5000, plot_type="GT", s=[36,30],fig_size=(8,6), output='Slide')
plot_impact_of_volumn_cdf(datasets=pcap_file[4:7],width=4096, k=5000, plot_type="Dirty", s=[36,22], fig_size=(8,6), output='Slide')


# # conference
plot_impact_of_volumn_cdf(datasets=pcap_file[4:7],width=4096, k=5000, plot_type="GT", s=[28,22], output='Conference')
plot_impact_of_volumn_cdf(datasets=pcap_file[4:7],width=4096, k=5000, plot_type="Dirty", s=[28,22], output='Conference')

# # thesis
plot_impact_of_volumn_cdf(datasets=pcap_file[4:7],width=4096, k=5000, plot_type="GT", s=[24,22], output='Thesis')
plot_impact_of_volumn_cdf(datasets=pcap_file[4:7],width=4096, k=5000, plot_type="Dirty", s=[24,22], output='Thesis')
# Out:
# 6
# /tmp/ipykernel_36582/3155821138.py:89: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 10000)
# 6
# 6
# 6
# /tmp/ipykernel_36582/3155821138.py:89: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 10000)
# 6
# /tmp/ipykernel_36582/3155821138.py:89: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 10000)
# 6
# /tmp/ipykernel_36582/3155821138.py:89: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 10000)

# %% [markdown]
# ---

# %%
def plot_wmrd_comparison(datasets, widths, fs=[24,20,18]):
    
    testing_fsd = {}
    profiler_offline_avg_fsd = {}
    profiler_gt_avg_fsd = {}
    
    # Prepare origin fsd
    pcap_folder = "/home/ming/SketchMercator/pattern_detection/traffic_generator/fs_dist_new/"
    
    # prepare testing avg fsd
    for w in widths:
        testing_fsd[w] = {}
        testing_fsd[w] = prepare_testing_fsd_data(datasets=datasets, width=w)
        
        # prepare profiler offline avg fsd
        profiler_offline_avg_fsd[w] = {}
        profiler_offline_fsd = prepare_profiler_offline_fsd_data(datasets=datasets, width=w)
        for name, fsd_list in profiler_offline_fsd.items():
            profiler_offline_avg_fsd[w][name] = get_avg_fsd(fsd_list)
            
    # prepare profiler gt avg fsd
    profiler_gt_fsd = prepare_profiler_offline_gt_fsd_data(datasets=datasets, width=4096)
    for name, fsd_list in profiler_gt_fsd.items():
        profiler_gt_avg_fsd[name] = get_avg_fsd(fsd_list)
            
    
    xticks = [f'{int(w*16/1024)}KB' for w in widths]
        
    MRDs_GT = []
    MRDs_Dirty = []
    # GT
    for d in datasets:
        single_MRDs = []
        # GT_fsd = get_fsd_dict(pcap_folder+d[:-9]+'.txt')
        GT_fsd = profiler_gt_avg_fsd[d[:-9]]
        for w in widths:
            total_mrd = 0.0
            for fsd in testing_fsd[w][d[:-9]]:
                total_mrd += calculate_mrd(normalize_fsd(GT_fsd), normalize_fsd(fsd))
            single_MRDs.append(round(total_mrd/len(testing_fsd[w][d[:-9]]), 2))
        
        MRDs_GT.append(single_MRDs)
        
    # Dirty
    for d in datasets:
        single_MRDs = []
        for w in widths:
            total_mrd = 0.0
            for fsd in testing_fsd[w][d[:-9]]:
                total_mrd += calculate_mrd(normalize_fsd(profiler_offline_avg_fsd[w][d[:-9]]), normalize_fsd(fsd))
            single_MRDs.append(round(total_mrd/len(testing_fsd[w][d[:-9]]), 2))
        
        MRDs_Dirty.append(single_MRDs)
        
    MRDs = [MRDs_GT, MRDs_Dirty]
        
    labels = list(testing_fsd[widths[0]].keys())
    # colors = {'caida':'tab:green', 'zipf2': 'tab:orange', 'zipf1':'tab:blue'}
    colors = {'500w':'tab:red', '250w':'tab:blue', '125w':'tab:orange', '50w':'tab:green'}
    hatches = {'500w':'////', '250w':'XX', '125w':'\\\\\\\\', '50w':'..'}
    legend_loc = ['lower left', 'lower left']
    titles = ['Sketch FSD vs. True FSD', 'Sketch FSD vs. Fake FSD']
    
    fig, axs = plt.subplots(1, 2, figsize=(10, 4), sharey=True)
    bar_width = 0.2
    for i, ax in enumerate(axs):
        ax.set_title(titles[i], fontsize=fs[1])
        mrd_data = MRDs[i]
        for j in range(len(mrd_data)):
            bar_positions = np.arange(len(mrd_data[0])) + j * bar_width
            ax.bar(bar_positions, mrd_data[j], width=bar_width, label=labels[j], zorder=3,
               color=colors[labels[j].split("-")[1]], edgecolor='black', hatch=hatches[labels[j].split("-")[1]])
    
        ax.set_xticks(np.arange(len(xticks)) + bar_width * (len(mrd_data) - 1) / 2)
        ax.set_xticklabels(xticks)
        ax.xaxis.set_tick_params(labelsize=fs[1])
        ax.yaxis.set_tick_params(labelsize=fs[1])
        # ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
        ax.grid(zorder=0)
        ax.spines[['top', 'right']].set_visible(False)
        
        if datasets[0].split("-")[0] == "zipf1":
            ax.legend(fontsize=fs[2], loc=legend_loc[i])
        else:
            ax.legend(fontsize=fs[2])
    
    fig.text(0.5, -0.02, 'Memory', ha='center', fontsize=fs[0])
    fig.text(-0.01, 0.5, 'WMRD', va='center', rotation='vertical', fontsize=fs[0])
    # plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)
    # plt.suptitle(f'Comparison of WMRD ({datasets[0].split("-")[0]})', fontsize=20)
    
    plt.tight_layout()
    plt.show()

# %%
def plot_wmrd_comparison_indep(datasets, widths, fig_size=(6,5), fs=[24,22], output='Thesis'):
    
    testing_fsd = {}
    profiler_offline_avg_fsd = {}
    profiler_gt_avg_fsd = {}
    
    # Prepare origin fsd
    pcap_folder = "/home/ming/SketchMercator/pattern_detection/traffic_generator/fs_dist_new/"
    
    # prepare testing avg fsd
    for w in widths:
        testing_fsd[w] = {}
        testing_fsd[w] = prepare_testing_fsd_data(datasets=datasets, width=w)
        
        # prepare profiler offline avg fsd
        profiler_offline_avg_fsd[w] = {}
        profiler_offline_fsd = prepare_profiler_offline_fsd_data(datasets=datasets, width=w)
        for name, fsd_list in profiler_offline_fsd.items():
            profiler_offline_avg_fsd[w][name] = get_avg_fsd(fsd_list)
            
    # prepare profiler gt avg fsd
    profiler_gt_fsd = prepare_profiler_offline_gt_fsd_data(datasets=datasets, width=4096)
    for name, fsd_list in profiler_gt_fsd.items():
        profiler_gt_avg_fsd[name] = get_avg_fsd(fsd_list)
            
    
    xticks = [f'{int(w*16/1024)}KB' for w in widths]
        
    MRDs_GT = []
    MRDs_Dirty = []
    # GT
    for d in datasets:
        single_MRDs = []
        # GT_fsd = get_fsd_dict(pcap_folder+d[:-9]+'.txt')
        GT_fsd = profiler_gt_avg_fsd[d[:-9]]
        for w in widths:
            total_mrd = 0.0
            for fsd in testing_fsd[w][d[:-9]]:
                total_mrd += calculate_mrd(normalize_fsd(GT_fsd), normalize_fsd(fsd))
            single_MRDs.append(round(total_mrd/len(testing_fsd[w][d[:-9]]), 2))
        
        MRDs_GT.append(single_MRDs)
        
    # Dirty
    for d in datasets:
        single_MRDs = []
        for w in widths:
            total_mrd = 0.0
            for fsd in testing_fsd[w][d[:-9]]:
                total_mrd += calculate_mrd(normalize_fsd(profiler_offline_avg_fsd[w][d[:-9]]), normalize_fsd(fsd))
            single_MRDs.append(round(total_mrd/len(testing_fsd[w][d[:-9]]), 2))
        
        MRDs_Dirty.append(single_MRDs)
        
    MRDs = [MRDs_GT, MRDs_Dirty]
        
    labels = list(testing_fsd[widths[0]].keys())
    # colors = {'caida':'tab:green', 'zipf2': 'tab:orange', 'zipf1':'tab:blue'}
    mapping = {'500w':'5000k', '250w':'2500k', '125w':'1250k', '50w':'500k'}
    colors = {'500w':'tab:red', '250w':'tab:blue', '125w':'tab:orange', '50w':'tab:green'}
    hatches = {'500w':'////', '250w':'XX', '125w':'\\\\\\\\', '50w':'..'}
    legend_loc = ['upper right', 'lower left']
    yticks = [0, 0.1, 0.2]
    titles = ['Sketch FSD vs. True FSD', 'Sketch FSD vs. Fake FSD']
    max_val = -1
    
    for i, mrd_data in enumerate(MRDs):
        fig, ax = plt.subplots(figsize=fig_size)
        bar_width = 0.2
    
        for j in range(len(mrd_data)):
            bar_positions = np.arange(len(mrd_data[0])) + j * bar_width
            ax.bar(bar_positions, mrd_data[j], width=bar_width, label=f'{labels[j].split("-")[0]}-{mapping[labels[j].split("-")[1]]}', zorder=3,
               color=colors[labels[j].split("-")[1]], edgecolor='black', hatch=hatches[labels[j].split("-")[1]])
            
            max_val = max(max_val, max(mrd_data[j]))
    
        print(max_val)
        ax.set_xticks(np.arange(len(xticks)) + bar_width * (len(mrd_data) - 1) / 2)
        ax.set_xticklabels(xticks)
        ax.set_ylim(0, max_val)
        ax.xaxis.set_tick_params(labelsize=fs[1])
        ax.yaxis.set_tick_params(labelsize=fs[1])
        # ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
        ax.grid(zorder=0)
        ax.spines[['top', 'right']].set_visible(False)
        
        if datasets[0].split("-")[0] == "zipf1":
            ax.legend(fontsize=fs[1], loc=legend_loc[0], handlelength=0.9, columnspacing=0.5)
        else:
            ax.legend(fontsize=fs[1], handlelength=0.9, columnspacing=0.5)

        ax.set_xlabel('Memory size', fontsize=fs[0])
        ax.set_ylabel('WMRD', fontsize=fs[0])
        # fig.text(0.5, -0.02, 'Memory', ha='center', fontsize=fs[0])
        # fig.text(-0.01, 0.5, 'WMRD', va='center', rotation='vertical', fontsize=fs[0])
        # plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)
        # plt.suptitle(f'Comparison of WMRD ({datasets[0].split("-")[0]})', fontsize=20)
        
        plt.tight_layout()
        if output != '':
            if i == 0:
                plt.savefig(f'../../{output}/PI-FSD/WMRD_true_{datasets[0].split("-")[0]}.pdf')
            else:
                plt.savefig(f'../../{output}/PI-FSD/WMRD_fake_{datasets[0].split("-")[0]}.pdf')
        plt.show()

# %%
# slide
# # plot_wmrd_comparison(datasets=pcap_file[:4], widths=[2048, 4096, 8192, 16384])
# plot_wmrd_comparison(datasets=pcap_file[4:7], widths=[2048, 4096, 8192, 16384])
# # plot_wmrd_comparison(datasets=pcap_file[7:10], widths=[2048, 4096, 8192, 16384])

# # conference
plot_wmrd_comparison_indep(datasets=pcap_file[4:7], widths=[2048, 4096, 8192, 16384], fs=[28,22], output='Conference', fig_size=(6,5))

# # thesis
plot_wmrd_comparison_indep(datasets=pcap_file[4:7], widths=[2048, 4096, 8192, 16384], fs=[26,24], output='Thesis', fig_size=(8,6))
# Out:
# 1.17
# 1.17
# 1.17
# 1.17

# %% [markdown]
# ---

# %%
def plot_mrd_between_est_offline(fs=[34,18,22]):
    # prepare profiler avg dirty fsd
    profiler_fsd = prepare_profiler_offline_fsd_data(datasets=pcap_file[:10], width=4096)
    profiler_avg_fsd = {}
    for name, fsd_list in profiler_fsd.items():
        profiler_avg_fsd[name] = get_avg_fsd(fsd_list)
        
    # prepare testing avg fsd
    testing_fsd = prepare_testing_fsd_data(datasets=pcap_file[:10], width=4096)
    testing_avg_fsd = {}
    for name, fsd_list in testing_fsd.items():
        testing_avg_fsd[name] = get_avg_fsd(fsd_list[:10])
        
    MRDs = []
    # adjust dataset order
    labels = list(profiler_avg_fsd.keys())
    # indexs = ['A1', 'A2', 'A3', 'A4', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']
    indexs = [f'{d[:-9].split("-")[0]}\n{d[:-9].split("-")[1]}' for d in pcap_file[:10]]
    
    # ## cal by avg fsd
    # for testing_name, t_fsd in testing_avg_fsd.items():
    #     single_MRDs = []
    #     for profiler_name, p_fsd in profiler_avg_fsd.items():
    #         mrd = round(calculate_mrd(p_fsd, t_fsd), 2)
    #         single_MRDs.append(mrd)
    #     MRDs.append(single_MRDs)
    
    # cal by avg mrd
    for testing_name, t_fsd in testing_fsd.items():
        single_MRDs = []
        for profiler_name, p_fsd in profiler_avg_fsd.items():
            total_mrd = 0.0
            for fsd in t_fsd:
                # mrd = calculate_mrd(p_fsd, fsd)
                mrd = calculate_mrd(normalize_fsd(p_fsd), normalize_fsd(fsd))
                total_mrd += mrd
            single_MRDs.append(round(total_mrd/len(t_fsd), 2))
        MRDs.append(single_MRDs)
    
    # Plot heatmap
    color = 'Oranges'
    plt.figure(figsize=(12, 12))
    plt.imshow(MRDs, cmap=color , interpolation='nearest')

    # Add annotations for each cell
    for i in range(len(MRDs)):
        for j in range(len(MRDs[i])):
            plt.text(j, i, f'{MRDs[i][j]:.2f}', ha='center', va='center', color='black', fontsize=fs[2])

    plt.xticks(np.arange(len(labels)), indexs, rotation=0, fontsize=fs[1])
    plt.yticks(np.arange(len(labels)), indexs, rotation=0, fontsize=fs[1])
    

    plt.xlabel('Fake FSD', fontsize=fs[0])
    plt.ylabel('Sketch FSD', fontsize=fs[0])
    # plt.title('WMRD between Sketch-DIST & Dirty-DIST', fontsize=20)
    cbar = plt.colorbar(shrink=0.7)  # Add colorbar
    cbar.ax.tick_params(labelsize=fs[2])
    # for i, label in enumerate(labels):
    #     plt.text(len(labels)+2.5, i, f'{indexs[i]} = {label}', ha='center', va='center', rotation=0)
        
    for i in range(len(MRDs)):
        min_value_index = np.argmin(MRDs[i])  # find idx with min val
        plt.gca().add_patch(plt.Rectangle((min_value_index-0.5, i-0.5), 1, 1, fill=False, edgecolor='Black', linewidth=3))
        
    plt.tight_layout()
    plt.show()

# %%
def plot_mrd_between_est_gt(fs=[34,18,22]):
    # prepare profiler avg gt fsd
    profiler_fsd = prepare_profiler_offline_gt_fsd_data(datasets=pcap_file[:10], width=4096)
    profiler_avg_fsd = {}
    for name, fsd_list in profiler_fsd.items():
        profiler_avg_fsd[name] = get_avg_fsd(fsd_list)
        
    # prepare testing avg fsd
    testing_fsd = prepare_testing_fsd_data(datasets=pcap_file[:10])
    testing_avg_fsd = {}
    for name, fsd_list in testing_fsd.items():
        testing_avg_fsd[name] = get_avg_fsd(fsd_list)
        
    # prepare testing gt avg fsd
    # testing_gt_fsd = prepare_testing_gt_fsd_data(datasets=pcap_file[:10])
    # testing_gt_avg_fsd = {}
    # for name, fsd_list in testing_gt_fsd.items():
    #     testing_gt_avg_fsd[name] = get_avg_fsd(fsd_list)
        
    pcap_folder = "/home/ming/SketchMercator/pattern_detection/traffic_generator/fs_dist_new/"
        
    # adjust dataset order
    labels = list(testing_fsd.keys())
    # indexs = ['A1', 'A2', 'A3', 'A4', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3']
    indexs = [f'{d[:-9].split("-")[0]}\n{d[:-9].split("-")[1]}' for d in pcap_file[:10]]
    
    MRDs = []
    # ## cal by avg fsd
    # for testing_name, t_fsd in testing_avg_fsd.items():
    #     single_MRDs = []
    #     for profiler_name, p_fsd in testing_gt_avg_fsd.items():
    #         mrd = round(calculate_mrd(p_fsd, t_fsd), 2)
    #         single_MRDs.append(mrd)
    #     MRDs.append(single_MRDs)
    
    # cal by avg mrd
    for testing_name, t_fsd in testing_fsd.items():
        single_MRDs = []
        for profiler_name, p_fsd in profiler_avg_fsd.items():
            total_mrd = 0.0
            for fsd in t_fsd:
                # mrd = calculate_mrd(p_fsd, fsd)
                mrd = calculate_mrd(normalize_fsd(p_fsd), normalize_fsd(fsd))
                total_mrd += mrd
            single_MRDs.append(round(total_mrd/len(t_fsd), 2))
        MRDs.append(single_MRDs)
    
    # Plot heatmap
    color = 'Greens'
    plt.figure(figsize=(12, 12))
    plt.imshow(MRDs, cmap=color , interpolation='nearest')

    # Add annotations for each cell
    for i in range(len(MRDs)):
        for j in range(len(MRDs[i])):
            plt.text(j, i, f'{MRDs[i][j]:.2f}', ha='center', va='center', color='black', fontsize=fs[2])

    plt.xticks(np.arange(len(labels)), indexs, rotation=0, fontsize=fs[1])
    plt.yticks(np.arange(len(labels)), indexs, rotation=0, fontsize=fs[1])
    

    plt.xlabel('True FSD', fontsize=fs[0])
    plt.ylabel('Sketch FSD', fontsize=fs[0])
    # plt.title('WMRD between Sketch-DIST & GT-DIST', fontsize=20)
    cbar = plt.colorbar(shrink=0.7)  # Add colorbar
    cbar.ax.tick_params(labelsize=fs[2])
    # for i, label in enumerate(labels):
    #     plt.text(len(labels)+2.5, i, f'{indexs[i]} = {label}', ha='center', va='center', rotation=0)
        
    for i in range(len(MRDs)):
        min_value_index = np.argmin(MRDs[i])  # find idx with min val
        plt.gca().add_patch(plt.Rectangle((min_value_index-0.5, i-0.5), 1, 1, fill=False, edgecolor='Black', linewidth=3))
    
    plt.tight_layout()
    plt.show()

# %%
plot_mrd_between_est_offline()
plot_mrd_between_est_gt()
