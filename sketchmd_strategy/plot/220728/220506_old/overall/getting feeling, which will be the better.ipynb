# %%
import os
import sys
import argparse
sys.path.append("../..")
sys.path.append("../../..")
from lib.logging import print_msg
from lib.read_data import data_read

def load_data(path):
    print(path)
    data = {}
    for pkl_name in sorted(os.listdir(path)):
        if ".pkl" in pkl_name:
            print(pkl_name)
            data[int(pkl_name.split(".pkl")[0])] = data_read(path, pkl_name)
    return data

result_path = "../../workload_manage/five_workloads/result"

data = {}

for workload_name in sorted(os.listdir(result_path)):
    print(workload_name)
    if workload_name.startswith("workload"):
        data[workload_name] = {}


        for run_name in ["bf", "gd"]:
            if run_name == "gd":
                result_search_path_temp = os.path.join(result_path, workload_name, run_name)
                for timeout_name in sorted(os.listdir(result_search_path_temp)):
                    if "_" in timeout_name:
                        result_search_path = os.path.join(result_search_path_temp, timeout_name)
                        data[workload_name][f"gd_{timeout_name}"] = load_data(result_search_path)
            else:
                result_search_path = os.path.join(result_path, workload_name, run_name)
                data[workload_name][run_name] = load_data(result_search_path)
# Out:
# workload_1
# ../../workload_manage/five_workloads/result/workload_1/bf
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 14.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 2.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 24.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 28.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/bf 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_1/gd/0_0
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/0_0 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_1/gd/5_5
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_1/gd/5_5 8.pkl
# [success]
# workload_2
# ../../workload_manage/five_workloads/result/workload_2/bf
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 2.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/bf 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_2/gd/0_0
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/0_0 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_2/gd/5_5
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_2/gd/5_5 8.pkl
# [success]
# workload_3
# ../../workload_manage/five_workloads/result/workload_3/bf
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 28.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/bf 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_3/gd/0_0
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/0_0 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_3/gd/5_5
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_3/gd/5_5 8.pkl
# [success]
# workload_4
# ../../workload_manage/five_workloads/result/workload_4/bf
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 22.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 28.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/bf 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_4/gd/0_0
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/0_0 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_4/gd/5_5
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_4/gd/5_5 8.pkl
# [success]
# workload_5
# ../../workload_manage/five_workloads/result/workload_5/bf
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 26.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/bf 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_5/gd/0_0
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/0_0 8.pkl
# [success]
# ../../workload_manage/five_workloads/result/workload_5/gd/5_5
# 10.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 10.pkl
# [success]
# 12.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 12.pkl
# [success]
# 14.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 14.pkl
# [success]
# 16.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 16.pkl
# [success]
# 18.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 18.pkl
# [success]
# 2.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 2.pkl
# [success]
# 20.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 20.pkl
# [success]
# 22.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 22.pkl
# [success]
# 24.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 24.pkl
# [success]
# 26.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 26.pkl
# [success]
# 28.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 28.pkl
# [success]
# 30.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 30.pkl
# [success]
# 4.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 4.pkl
# [success]
# 6.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 6.pkl
# [success]
# 8.pkl
# [load output] ../../workload_manage/five_workloads/result/workload_5/gd/5_5 8.pkl
# [success]

# %%
import numpy as np

def get_reduction_rate(baseline, opt):
    return (baseline - opt)/(baseline+0.000001) * 100

from statistics import median

import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['hatch.linewidth'] = 0.1
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
width = 0.1

markerst1 = 's'
markerst2 = 'p'
markerst3 = '^'
markerst4 = '*'
markerst5 = '|'
width = 0.1
colors = ['C0', 'C0', 'C1', 'C1', 'C2', 'C2']
run_name = "gd_5_5"
key_list = [i*2 for i in range(1, 16)]
for key in key_list:
#     fig, ax = plt.subplots(figsize=(5, 3))
    xaxis_title = str(key)
    print(run_name)
    result = {}
    for resource in ["hashcall", "salu", "sram"]:
        result[resource] = {}
        result[resource]["before"] = []
        result[resource]["after"] = []
        
    fig, ax = plt.subplots(figsize=(10, 5))
    workload_list = ["W1", "W2", "W3", "W4", "W5"]

#     xlabel = [0, 1, 2, 3, 4]
    xlabel = np.arange(5)
    
    for workload in ["workload_1", "workload_2", "workload_3", "workload_4", "workload_5"]:
        df = data[workload][run_name][key]["avg_resource"]
        for resource in ["hashcall", "salu", "sram"]:
            result[resource]["before"].append(df["before"][resource])
            result[resource]["after"].append(df["after"][resource])
    

    i = 0

    for individual_resource, offset in zip(["hashcall", "salu", "sram"], [-3, 0, 3]):
        ax.bar(xlabel+(offset-1)*width, result[individual_resource]["before"], width, label="before " + individual_resource,
            # error_kw=dict(lw=0.5, capsize=1.,capthick=0.5),# ecolor=colors[0]),
            hatch='...', color=colors[i], edgecolor='black')

        ax.bar(xlabel+offset*width, result[individual_resource]["after"], width, label="after " + individual_resource,
               hatch='+++',color=colors[i+1], edgecolor='#000000')
        i += 2

    ax.yaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%d'))
    # fig.canvas.draw()
    # ax.set_title(individual_resource + ' Usage ($\\%$) before vs after', fontsize=30)
    ax.set_xticks(np.arange(len(workload_list)))
    ax.set_xticklabels(workload_list, fontsize=20)
    ax.set_xlabel(xaxis_title, fontsize=20)
    ax.set_yticks(np.arange(0, 350, step=50))
    ax.tick_params(axis='y', labelsize=20)
    ax.set_ylabel('Resource  Usage ($\\%$)', fontsize=20)
    ax.set_ylim([0, 250])
    ax.legend(ncol=3, fontsize=15)
    ax.axhline(y=100, color='red', linestyle="--", linewidth=2)
    # ax.legend(ncol=2, frameon=True, loc='best', borderaxespad=0.1,
    # handlelength=0.6, handletextpad=0.2, columnspacing=0.3, fontsize=20,
    # framealpha=0.5)
    ax.minorticks_off()
    plt.grid(color='gray', linestyle='--', linewidth=1, axis='y')
    plt.tight_layout()
#     plt.savefig("beforeafter.png", format="png", bbox_inches='tight')
    plt.show()
    plt.clf()
# Out:
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
# gd_5_5
