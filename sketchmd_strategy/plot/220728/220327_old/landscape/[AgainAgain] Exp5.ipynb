# %%
import plot.plot_common as pc
import importlib
importlib.reload(pc)

out = "../../workload_manage/landscape/output"
filename = "landscape3.pkl"

output_dict = pc.data_read(out, filename)
# Out:
# [load output]
# [success]

# %%
candidate_list = [output_dict["gd"]["bf"]["bf"], output_dict["o5"]]
name_list = ["gd_bf_bf", "o5"]

# %%
# [11] avg(73%) / 74% reduction, looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload3-10")
# Out:
# avg performance: 72.76366472957488
# median performance: 72.45435026563376
# 24
# 72.47074969324213
# overall     90.555556
# salu        52.083333
# hashcall    34.722222
# sram         3.750000
# dtype: float64
# overall     29.166667
# salu        14.583333
# hashcall    12.500000
# sram         2.083333
# dtype: float64
# overall     60.798611
# salu        35.416667
# hashcall    23.611111
# sram         1.770833
# dtype: float64
# overall     12.500000
# hashcall     4.166667
# salu         6.250000
# sram         2.083333
# dtype: float64
# hashcall    71.428570
# overall     72.470750
# salu        76.190475
# sram        24.528297
# dtype: float64
#
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]  CountingBloomFilter                [3]     1     1    10     1   2048     1
# [  0]              Entropy                [3]     3     1    10     1   2048     1
# [  0]              Entropy                [3]     3     1    20     1   4096     1
# [  0]             CountMin                [3]     4     1    10     1   2048     1
# [  0]             CountMin                [3]     4     1    20     1   4096     1
# [  0]                 Kary                [3]     5     1    10     1   4096     1
# [  0]                 Kary                [3]     5     1    20     1   4096     1
# [  0]  CountingBloomFilter             [1, 3]     1     1    10     1   2048     1
# [  0]  CountingBloomFilter             [1, 3]     1     1    20     1   1024     1
# [  0]              Entropy             [1, 3]     3     1    10     1   1024     1
# [  0]              Entropy             [1, 3]     3     1    20     1   1024     1
# [  0]             CountMin             [1, 3]     4     1    10     1   4096     1
# [  0]             CountMin             [1, 3]     4     1    20     1   4096     1
# [  0]                 Kary             [1, 3]     5     1    20     1   1024     1
# [  0]  CountingBloomFilter                [0]     1     1    10     1   2048     1
# [  0]              Entropy                [0]     3     1    10     1   4096     1
# [  0]              Entropy                [0]     3     1    20     1   4096     1
# [  0]             CountMin                [0]     4     1    10     1   1024     1
# [  0]             CountMin                [0]     4     1    20     1   1024     1
# [  0]                 Kary                [0]     5     1    10     1   4096     1
# [  0]  CountingBloomFilter             [0, 1]     1     1    10     1   4096     1
# [  0]              Entropy             [0, 1]     3     1    10     1   2048     1
# [  0]              Entropy             [0, 1]     3     1    20     1   1024     1
# [  0]                 Kary             [0, 1]     5     1    10     1   1024     1
# [  0]                 Kary             [0, 1]     5     1    20     1   4096     1
# -------------------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  1]  CountingBloomFilter                [3]     1     1    10     1   2048     1
# [  2]              Entropy                [3]     3     1    10     1   2048     1
# [  4]             CountMin                [3]     4     1    10     1   2048     1
# [  6]                 Kary                [3]     5     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  3]              Entropy                [3]     3     1    20     1   4096     1
# [  5]             CountMin                [3]     4     1    20     1   4096     1
# [  7]                 Kary                [3]     5     1    20     1   4096     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  8]  CountingBloomFilter             [1, 3]     1     1    10     1   2048     1
# [ 10]              Entropy             [1, 3]     3     1    10     1   1024     1
# [ 12]             CountMin             [1, 3]     4     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  9]  CountingBloomFilter             [1, 3]     1     1    20     1   1024     1
# [ 11]              Entropy             [1, 3]     3     1    20     1   1024     1
# [ 13]             CountMin             [1, 3]     4     1    20     1   4096     1
# [ 14]                 Kary             [1, 3]     5     1    20     1   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 15]  CountingBloomFilter                [0]     1     1    10     1   2048     1
# [ 16]              Entropy                [0]     3     1    10     1   4096     1
# [ 18]             CountMin                [0]     4     1    10     1   1024     1
# [ 20]                 Kary                [0]     5     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 17]              Entropy                [0]     3     1    20     1   4096     1
# [ 19]             CountMin                [0]     4     1    20     1   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 23]              Entropy             [0, 1]     3     1    20     1   1024     1
# [ 25]                 Kary             [0, 1]     5     1    20     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#           ---------------------------------------------------------------------------
# [ 21]  CountingBloomFilter             [0, 1]     1     1    10     1   4096     1
# [ 22]              Entropy             [0, 1]     3     1    10     1   2048     1
# [ 24]                 Kary             [0, 1]     5     1    10     1   1024     1
#           ---------------------------------------------------------------------------

# %%
# [8] avg(49%) / 48% reduction, looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload3-7")
# Out:
# avg performance: 47.67316380306693
# median performance: 47.72233843927059
# 2
# 47.725276879999015
# overall     223.402778
# salu        125.000000
# hashcall     90.277778
# sram          8.125000
# dtype: float64
# overall     132.326394
# salu         62.500000
# hashcall     59.722222
# sram         10.104167
# dtype: float64
# overall     53.645833
# salu        31.250000
# hashcall    20.833333
# sram         1.562500
# dtype: float64
# overall     12.500000
# hashcall     4.166667
# salu         6.250000
# sram         2.083333
# dtype: float64
# hashcall    42.500000
# overall     47.725277
# salu        56.000000
# sram       -25.806449
# dtype: float64
#
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]  CountingBloomFilter                [1]     1     2    10     3   2048     1
# [  0]              Entropy                [1]     3     1    10     3   2048     1
# [  0]              Entropy                [1]     3     2    20     4   4096     1
# [  0]                 MRAC                [1]     6     2    20     1   2048     4
# [  0]              Entropy                [0]     3     1    20     4   2048     1
# [  0]              Entropy                [0]     3     2    20     3   2048     1
# [  0]             CountMin                [0]     4     2    20     2   1024     1
# [  0]                 Kary                [0]     5     1    20     2   4096     1
# [  0]                 Kary                [0]     5     2    20     4   4096     1
# [  0]                 MRAC                [0]     6     2    20     1   1024     4
# [  0]              Entropy             [0, 2]     3     1    20     2   4096     1
# [  0]              Entropy             [0, 2]     3     2    10     4   1024     1
# [  0]             CountMin             [0, 2]     4     2    10     2   4096     1
# [  0]                 Kary             [0, 2]     5     2    20     5   2048     1
# [  0]                 MRAC             [0, 2]     6     1    10     1   2048     4
# [  0]                 MRAC             [0, 2]     6     1    20     1   1024     4
# [  0]  CountingBloomFilter             [0, 1]     1     1    10     2   1024     1
# [  0]  CountingBloomFilter             [0, 1]     1     1    20     4   1024     1
# [  0]              Entropy             [0, 1]     3     1    10     1   2048     1
# [  0]              Entropy             [0, 1]     3     2    10     1   2048     1
# [  0]             CountMin             [0, 1]     4     1    20     1   1024     1
# [  0]             CountMin             [0, 1]     4     2    10     2   1024     1
# [  0]                 Kary             [0, 1]     5     1    20     4   2048     1
# [  0]                 Kary             [0, 1]     5     2    20     2   4096     1
# [  0]                 MRAC             [0, 1]     6     1    20     1   1024     4
# -------------------------------------------------------------------------------------
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  1]  CountingBloomFilter                [1]     1     2    10     3   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  2]              Entropy                [1]     3     1    10     3   2048     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  3]              Entropy                [1]     3     2    20     4   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 20]              Entropy             [0, 1]     3     2    10     1   2048     1
# [ 22]             CountMin             [0, 1]     4     2    10     2   1024     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 24]                 Kary             [0, 1]     5     2    20     2   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#           ---------------------------------------------------------------------------
# [  4]                 MRAC                [1]     6     2    20     1   2048     4
#           ---------------------------------------------------------------------------
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  5]              Entropy                [0]     3     1    20     4   2048     1
# [  8]                 Kary                [0]     5     1    20     2   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  6]              Entropy                [0]     3     2    20     3   2048     1
# [  7]             CountMin                [0]     4     2    20     2   1024     1
# [  9]                 Kary                [0]     5     2    20     4   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#           ---------------------------------------------------------------------------
# [ 10]                 MRAC                [0]     6     2    20     1   1024     4
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 12]              Entropy             [0, 2]     3     2    10     4   1024     1
# [ 13]             CountMin             [0, 2]     4     2    10     2   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 11]              Entropy             [0, 2]     3     1    20     2   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 14]                 Kary             [0, 2]     5     2    20     5   2048     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 15]                 MRAC             [0, 2]     6     1    10     1   2048     4
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 16]                 MRAC             [0, 2]     6     1    20     1   1024     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 17]  CountingBloomFilter             [0, 1]     1     1    10     2   1024     1
# [ 19]              Entropy             [0, 1]     3     1    10     1   2048     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 18]  CountingBloomFilter             [0, 1]     1     1    20     4   1024     1
# [ 21]             CountMin             [0, 1]     4     1    20     1   1024     1
# [ 23]                 Kary             [0, 1]     5     1    20     4   2048     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 25]                 MRAC             [0, 1]     6     1    20     1   1024     4
#           ---------------------------------------------------------------------------

# %%
# [5] avg(46%) -> this is infeasible, we need to reduce # of sketch instances
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload2-3")
# Out:
# avg performance: 46.49714307178475
# median performance: 46.41218108185751
# 41
# 46.48619211769554
# overall     328.263889
# salu        160.416667
# hashcall    134.722222
# sram         33.125000
# dtype: float64
# overall     255.902809
# salu         77.083333
# hashcall    115.277778
# sram         63.541667
# dtype: float64
# overall     192.5
# salu        112.5
# hashcall     75.0
# sram          5.0
# dtype: float64
# overall     22.777778
# hashcall     6.944444
# salu        10.416667
# sram         5.416667
# dtype: float64
# hashcall    41.721854
# overall     46.486192
# salu        67.938931
# sram       -80.874315
# dtype: float64
#
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  1]             CountMin                [3]     4     1    10     2   2048     1
# [  2]             CountMin                [3]     4     1    30     5   4096     1
# [  3]                 Kary                [3]     5     1    10     5   1024     1
# [  4]                 Kary                [3]     5     1    20     3   4096     1
# [  5]                 Kary                [3]     5     1    30     1   2048     1
# [  6]              UnivMon                [3]     7     1    20     2   1024    16
# [  7]             CountMin                [1]     4     1    10     1   2048     1
# [  8]                 Kary                [1]     5     1    10     3   2048     1
# [  9]              UnivMon                [1]     7     1    20     4   1024    16
# [ 10]              UnivMon                [1]     7     1    30     4   2048    16
# [ 11]          CountSketch                [0]     4     1    10     3   4096     1
# [ 12]             CountMin                [0]     4     1    20     3   4096     1
# [ 13]          CountSketch                [0]     4     1    30     4   2048     1
# [ 14]                 Kary                [0]     5     1    10     4   4096     1
# [ 15]             CountMin             [0, 2]     4     1    10     1   1024     1
# [ 16]             CountMin             [0, 2]     4     1    20     3   4096     1
# [ 17]          CountSketch             [0, 2]     4     1    30     3   1024     1
# [ 18]                 Kary             [0, 2]     5     1    20     3   4096     1
# [ 19]                 Kary             [0, 2]     5     1    30     1   1024     1
# [ 20]          CountSketch    [0, 1, 2, 3, 4]     4     1    10     2   4096     1
# [ 21]                 Kary    [0, 1, 2, 3, 4]     5     1    10     1   4096     1
# [ 22]                 Kary    [0, 1, 2, 3, 4]     5     1    20     5   4096     1
# [ 23]                 Kary    [0, 1, 2, 3, 4]     5     1    30     4   2048     1
# [ 24]              UnivMon    [0, 1, 2, 3, 4]     7     1    20     5   1024    16
# [ 25]              UnivMon    [0, 1, 2, 3, 4]     7     1    30     5   2048    16
# -------------------------------------------------------------------------------------
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  1]             CountMin                [3]     4     1    10     2   2048     1
# [  3]                 Kary                [3]     5     1    10     5   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  2]             CountMin                [3]     4     1    30     5   4096     1
# [  5]                 Kary                [3]     5     1    30     1   2048     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  4]                 Kary                [3]     5     1    20     3   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  7]             CountMin                [1]     4     1    10     1   2048     1
# [  8]                 Kary                [1]     5     1    10     3   2048     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  9]              UnivMon                [1]     7     1    20     4   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  6]              UnivMon                [3]     7     1    20     2   1024    16
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 20]          CountSketch    [0, 1, 2, 3, 4]     4     1    10     2   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 10]              UnivMon                [1]     7     1    30     4   2048    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 13]          CountSketch                [0]     4     1    30     4   2048     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 14]                 Kary                [0]     5     1    10     4   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 12]             CountMin                [0]     4     1    20     3   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 15]             CountMin             [0, 2]     4     1    10     1   1024     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 11]          CountSketch                [0]     4     1    10     3   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 17]          CountSketch             [0, 2]     4     1    30     3   1024     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 22]                 Kary    [0, 1, 2, 3, 4]     5     1    20     5   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 16]             CountMin             [0, 2]     4     1    20     3   4096     1
# [ 18]                 Kary             [0, 2]     5     1    20     3   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 19]                 Kary             [0, 2]     5     1    30     1   1024     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 21]                 Kary    [0, 1, 2, 3, 4]     5     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 24]              UnivMon    [0, 1, 2, 3, 4]     7     1    20     5   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 25]              UnivMon    [0, 1, 2, 3, 4]     7     1    30     5   2048    16
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#           ---------------------------------------------------------------------------
# [ 23]                 Kary    [0, 1, 2, 3, 4]     5     1    30     4   2048     1
#           ---------------------------------------------------------------------------

# %%
# [2] avg(36%) -> 38% This can be feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload1-3")
# Out:
# avg performance: 40.613115643807234
# median performance: 40.863844063211644
# 40
# 40.87920738345909
# overall     169.027778
# salu         91.666667
# hashcall     69.444444
# sram          7.916667
# dtype: float64
# overall     99.930562
# salu        50.000000
# hashcall    38.888889
# sram        11.041667
# dtype: float64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     40.879207
# salu        45.454545
# hashcall    43.999999
# sram       -39.473679
# dtype: float64
#
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]          BloomFilter                [0]     1     1    20     3     64     1
# [  0]       LinearCounting                [0]     2     1    20     1     32     1
# [  0]              Entropy                [0]     3     1    10     3   4096     1
# [  0]              Entropy                [0]     3     1    20     1   2048     1
# [  0]                 MRAC                [0]     6     1    10     1   2048     4
# [  0]                 MRAC                [0]     6     1    20     1   1024    16
# [  0]          BloomFilter             [0, 2]     1     1    10     3     32     1
# [  0]          BloomFilter             [0, 2]     1     1    20     2    128     1
# [  0]       LinearCounting             [0, 2]     2     1    10     1     64     1
# [  0]       LinearCounting             [0, 2]     2     1    20     1   4096     1
# [  0]              Entropy             [0, 2]     3     1    10     1   4096     1
# [  0]                 MRAC             [0, 2]     6     1    20     1   2048     4
# [  0]  CountingBloomFilter             [0, 1]     1     1    10     2   1024     1
# [  0]          BloomFilter             [0, 1]     1     1    20     1   1024     1
# [  0]              Entropy             [0, 1]     3     1    10     3   2048     1
# [  0]              Entropy             [0, 1]     3     1    20     1   1024     1
# [  0]                 MRAC             [0, 1]     6     1    10     1   2048     4
# [  0]  CountingBloomFilter       [0, 1, 2, 3]     1     1    10     4   4096     1
# [  0]  CountingBloomFilter       [0, 1, 2, 3]     1     1    20     2   2048     1
# [  0]       LinearCounting       [0, 1, 2, 3]     2     1    10     1   2048     1
# [  0]       LinearCounting       [0, 1, 2, 3]     2     1    20     1    128     1
# [  0]              Entropy       [0, 1, 2, 3]     3     1    10     4   4096     1
# [  0]              Entropy       [0, 1, 2, 3]     3     1    20     3   1024     1
# [  0]                 MRAC       [0, 1, 2, 3]     6     1    10     1   1024    16
# [  0]                 MRAC       [0, 1, 2, 3]     6     1    20     1   2048     4
# -------------------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  4]              Entropy                [0]     3     1    20     1   2048     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  1]          BloomFilter                [0]     1     1    20     3     64     1
# [  2]       LinearCounting                [0]     2     1    20     1     32     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  3]              Entropy                [0]     3     1    10     3   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  8]          BloomFilter             [0, 2]     1     1    20     2    128     1
# [ 10]       LinearCounting             [0, 2]     2     1    20     1   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 11]              Entropy             [0, 2]     3     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [  7]          BloomFilter             [0, 2]     1     1    10     3     32     1
# [  9]       LinearCounting             [0, 2]     2     1    10     1     64     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  5]                 MRAC                [0]     6     1    10     1   2048     4
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  6]                 MRAC                [0]     6     1    20     1   1024    16
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 12]                 MRAC             [0, 2]     6     1    20     1   2048     4
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 16]              Entropy             [0, 1]     3     1    20     1   1024     1
# [ 14]          BloomFilter             [0, 1]     1     1    20     1   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 13]  CountingBloomFilter             [0, 1]     1     1    10     2   1024     1
# [ 15]              Entropy             [0, 1]     3     1    10     3   2048     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 17]                 MRAC             [0, 1]     6     1    10     1   2048     4
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 19]  CountingBloomFilter       [0, 1, 2, 3]     1     1    20     2   2048     1
# [ 23]              Entropy       [0, 1, 2, 3]     3     1    20     3   1024     1
# [ 21]       LinearCounting       [0, 1, 2, 3]     2     1    20     1    128     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 18]  CountingBloomFilter       [0, 1, 2, 3]     1     1    10     4   4096     1
# [ 22]              Entropy       [0, 1, 2, 3]     3     1    10     4   4096     1
# [ 20]       LinearCounting       [0, 1, 2, 3]     2     1    10     1   2048     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 24]                 MRAC       [0, 1, 2, 3]     6     1    10     1   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 25]                 MRAC       [0, 1, 2, 3]     6     1    20     1   2048     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================

# %%
# [2] avg(22%) -> 21% This can be feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload1-1")
# Out:
# avg performance: 27.62515436496809
# median performance: 27.931930873412085
# 0
# 27.98911658266953
# overall     178.888889
# salu         89.583333
# hashcall     76.388889
# sram         12.916667
# dtype: float64
# overall     128.819469
# salu         52.083333
# hashcall     56.944444
# sram         19.791667
# dtype: float64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     27.989117
# salu        41.860465
# hashcall    25.454545
# sram       -53.225802
# dtype: float64
#
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]                  HLL                [3]     2     2    25     1   1024     1
# [  0]       LinearCounting                [3]     2     2    35     1     32     1
# [  0]              Entropy                [1]     3     1     5     2   4096     1
# [  0]                 MRAC                [1]     6     2    30     1   2048     4
# [  0]  CountingBloomFilter             [1, 3]     1     2    30     4   1024     1
# [  0]                  MRB             [1, 3]     2     1     5     1     32    16
# [  0]                 PCSA             [1, 3]     2     1    20     1   4096     1
# [  0]              Entropy             [1, 3]     3     2    20     2   4096     1
# [  0]          BloomFilter                [0]     1     2    30     1   4096     1
# [  0]                 MRAC                [0]     6     1     5     1   2048    16
# [  0]                 MRAC                [0]     6     1    10     1   1024     4
# [  0]                 MRAC                [0]     6     1    35     1   2048    16
# [  0]                 MRAC                [0]     6     2    25     1   1024     4
# [  0]              Entropy             [0, 2]     3     1     5     5   2048     1
# [  0]                 MRAC             [0, 2]     6     1    15     1   2048    16
# [  0]                 MRAC             [0, 2]     6     2     5     1   1024    16
# [  0]          BloomFilter             [0, 1]     1     1    10     5   1024     1
# [  0]              Entropy             [0, 1]     3     1    30     4   2048     1
# [  0]              Entropy             [0, 1]     3     2    25     2   2048     1
# [  0]                 MRAC             [0, 1]     6     1    10     1   2048     4
# [  0]                 MRAC             [0, 1]     6     2    20     1   1024    16
# [  0]              Entropy       [0, 1, 2, 3]     3     2     5     2   4096     1
# [  0]                 MRAC       [0, 1, 2, 3]     6     1    20     1   1024    16
# [  0]                 MRAC       [0, 1, 2, 3]     6     2    20     1   2048     4
# [  0]              Entropy    [0, 1, 2, 3, 4]     3     2    25     1   2048     1
# -------------------------------------------------------------------------------------
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  2]       LinearCounting                [3]     2     2    35     1     32     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  1]                  HLL                [3]     2     2    25     1   1024     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [  6]                  MRB             [1, 3]     2     1     5     1     32    16
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  9]          BloomFilter                [0]     1     2    30     1   4096     1
#           ---------------------------------------------------------------------------
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 14]              Entropy             [0, 2]     3     1     5     5   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 19]              Entropy             [0, 1]     3     2    25     2   2048     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 22]              Entropy       [0, 1, 2, 3]     3     2     5     2   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 25]              Entropy    [0, 1, 2, 3, 4]     3     2    25     1   2048     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 17]          BloomFilter             [0, 1]     1     1    10     5   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 18]              Entropy             [0, 1]     3     1    30     4   2048     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [  3]              Entropy                [1]     3     1     5     2   4096     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  4]                 MRAC                [1]     6     2    30     1   2048     4
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  5]  CountingBloomFilter             [1, 3]     1     2    30     4   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  7]                 PCSA             [1, 3]     2     1    20     1   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  8]              Entropy             [1, 3]     3     2    20     2   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 10]                 MRAC                [0]     6     1     5     1   2048    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 12]                 MRAC                [0]     6     1    35     1   2048    16
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 11]                 MRAC                [0]     6     1    10     1   1024     4
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 13]                 MRAC                [0]     6     2    25     1   1024     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 15]                 MRAC             [0, 2]     6     1    15     1   2048    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 16]                 MRAC             [0, 2]     6     2     5     1   1024    16
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 20]                 MRAC             [0, 1]     6     1    10     1   2048     4
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 21]                 MRAC             [0, 1]     6     2    20     1   1024    16
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 23]                 MRAC       [0, 1, 2, 3]     6     1    20     1   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 24]                 MRAC       [0, 1, 2, 3]     6     2    20     1   2048     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================
