# %%
import plot.plot_common as pc
import importlib
importlib.reload(pc)

out = "../../workload_manage/landscape/output"
filename = "landscape3.pkl"

output_dict = pc.data_read(out, filename)
# Out:
# [load output]
# [success]

# %%
import plot.plot_common as pc
import importlib
importlib.reload(pc)

candidate_list = [output_dict["gd"]["bf"]["bf"], output_dict["o5"]]
name_list = ["gd_bf_bf", "o5"]

ret = pc.data_parse_min_max(candidate_list, name_list)

core_data_dict = ret["core_data_dict"]
time_data_dict = ret["time_data_dict"]
key_list_dict = ret["key_list_dict"]
# Out:
# workload1-1 100
# workload1-2 100
# workload1-3 100
# workload2-1 100
# workload2-2 100
# workload2-3 100
# workload3-1 100
# workload3-5 100
# workload3-7 100
# workload3-8 100
# workload3-9 100
# workload3-10 100
# gd_bf_bf
# (12, 3, 4, 100)
# (12, 100)
# workload1-1 100
# workload1-2 100
# workload1-3 100
# workload2-1 100
# workload2-2 100
# workload2-3 100
# workload3-1 100
# workload3-5 100
# workload3-7 100
# workload3-8 100
# workload3-9 100
# workload3-10 100
# o5
# (12, 3, 4, 100)
# (12, 100)
# (3, 12, 4, 100)

# %%
import plot.plot_plot as pp
import importlib
importlib.reload(pp)

pp.overall_bar_plot(key_list_dict["gd_bf_bf"], core_data_dict["gd_bf_bf"], core_data_dict["o5"])
# Out:
# ['workload1-1', 'workload1-2', 'workload1-3', 'workload2-1', 'workload2-2', 'workload2-3', 'workload3-1', 'workload3-5', 'workload3-7', 'workload3-8', 'workload3-9', 'workload3-10']
# 0     27.625154
# 1     32.641114
# 2     40.613116
# 3     42.769952
# 4     46.000487
# 5     46.497143
# 6     35.620950
# 7     40.856065
# 8     47.673164
# 9     56.559168
# 10    63.649181
# 11    72.763665
# Name: overall, dtype: float64
# 0     27.625154
# 1     32.641114
# 2     40.613116
# 3     42.769952
# 4     46.000487
# 5     46.497143
# 6     35.620950
# 7     40.856065
# 8     47.673164
# 9     56.559168
# 10    63.649181
# 11    72.763665
# Name: overall, dtype: float64

# %%
import plot.plot_plot as pp
import importlib
importlib.reload(pp)

pp.resource_bar_plot(key_list_dict["gd_bf_bf"], core_data_dict["gd_bf_bf"], core_data_dict["o5"])
# Out:
# ['workload1-1', 'workload1-2', 'workload1-3', 'workload2-1', 'workload2-2', 'workload2-3', 'workload3-1', 'workload3-5', 'workload3-7', 'workload3-8', 'workload3-9', 'workload3-10']
# 0     31.306261
# 1     36.307215
# 2     43.568544
# 3     66.519890
# 4     68.585897
# 5     68.683839
# 6     48.974961
# 7     52.397981
# 8     58.050586
# 9     65.613730
# 10    68.584466
# 11    77.086400
# Name: hashcall, dtype: float64
# 31.306260951650223
# 77.08640000325708
# 0     29.213483
# 1     35.252762
# 2     43.915782
# 3     35.865304
# 4     39.513352
# 5     39.574993
# 6     32.804128
# 7     38.468246
# 8     41.523482
# 9     49.444551
# 10    60.329312
# 11    69.388556
# Name: salu, dtype: float64
# 29.213482782476913
# 69.38855579586065
# 0    -23.135851
# 1    -25.458079
# 2    -16.548741
# 3    -80.197315
# 4    -75.500854
# 5    -76.083256
# 6    -43.460041
# 7    -33.147050
# 8    -19.190759
# 9    -12.095253
# 10    21.755294
# 11    29.226882
# Name: sram, dtype: float64
# -80.19731474322411
# 29.226882460577457
