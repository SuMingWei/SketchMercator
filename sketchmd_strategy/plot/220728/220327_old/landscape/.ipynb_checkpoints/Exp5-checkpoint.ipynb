# %%
import plot.plot_common as pc
import importlib
importlib.reload(pc)

out = "../../workload_manage/landscape/output"
filename = "landscape.pkl"

output_dict = pc.data_read(out, filename)
# Out:
# [load output]
# [success]

# %%
candidate_list = [output_dict["gd"]["bf"]["bf"], output_dict["o5"]]
name_list = ["gd_bf_bf", "o5"]

# %%
# looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload3-10", 8)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  1]  CountingBloomFilter                [3]     1     1    10     3   1024     1
# [  2]              Entropy                [3]     3     1    10     3   4096     1
# [  3]              Entropy                [3]     3     1    20     3   2048     1
# [  4]             CountMin                [3]     4     1    10     3   1024     1
# [  5]                 Kary                [3]     5     1    10     3   1024     1
# [  6]                 Kary                [3]     5     1    20     3   2048     1
# [  7]  CountingBloomFilter             [0, 2]     1     1    20     3   2048     1
# [  8]              Entropy             [0, 2]     3     1    10     3   2048     1
# [  9]              Entropy             [0, 2]     3     1    20     3   4096     1
# [ 10]             CountMin             [0, 2]     4     1    10     3   4096     1
# [ 11]                 Kary             [0, 2]     5     1    10     3   4096     1
# [ 12]                 Kary             [0, 2]     5     1    20     3   1024     1
# [ 13]  CountingBloomFilter       [0, 1, 2, 3]     1     1    10     3   1024     1
# [ 14]              Entropy       [0, 1, 2, 3]     3     1    10     3   1024     1
# [ 15]              Entropy       [0, 1, 2, 3]     3     1    20     3   2048     1
# [ 16]             CountMin       [0, 1, 2, 3]     4     1    10     3   2048     1
# [ 17]                 Kary       [0, 1, 2, 3]     5     1    10     3   1024     1
# [ 18]                 Kary       [0, 1, 2, 3]     5     1    20     3   1024     1
# [ 19]  CountingBloomFilter    [0, 1, 2, 3, 4]     1     1    10     3   2048     1
# [ 20]  CountingBloomFilter    [0, 1, 2, 3, 4]     1     1    20     3   2048     1
# [ 21]              Entropy    [0, 1, 2, 3, 4]     3     1    20     3   1024     1
# [ 22]             CountMin    [0, 1, 2, 3, 4]     4     1    10     3   2048     1
# [ 23]             CountMin    [0, 1, 2, 3, 4]     4     1    20     3   4096     1
# [ 24]                 Kary    [0, 1, 2, 3, 4]     5     1    10     3   1024     1
# [ 25]                 Kary    [0, 1, 2, 3, 4]     5     1    20     3   4096     1
# -------------------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  1]  CountingBloomFilter                [3]     1     1    10     3   1024     1
# [  2]              Entropy                [3]     3     1    10     3   4096     1
# [  4]             CountMin                [3]     4     1    10     3   1024     1
# [  5]                 Kary                [3]     5     1    10     3   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  7]  CountingBloomFilter             [0, 2]     1     1    20     3   2048     1
# [  9]              Entropy             [0, 2]     3     1    20     3   4096     1
# [ 12]                 Kary             [0, 2]     5     1    20     3   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 13]  CountingBloomFilter       [0, 1, 2, 3]     1     1    10     3   1024     1
# [ 14]              Entropy       [0, 1, 2, 3]     3     1    10     3   1024     1
# [ 16]             CountMin       [0, 1, 2, 3]     4     1    10     3   2048     1
# [ 17]                 Kary       [0, 1, 2, 3]     5     1    10     3   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 19]  CountingBloomFilter    [0, 1, 2, 3, 4]     1     1    10     3   2048     1
# [ 22]             CountMin    [0, 1, 2, 3, 4]     4     1    10     3   2048     1
# [ 24]                 Kary    [0, 1, 2, 3, 4]     5     1    10     3   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 20]  CountingBloomFilter    [0, 1, 2, 3, 4]     1     1    20     3   2048     1
# [ 21]              Entropy    [0, 1, 2, 3, 4]     3     1    20     3   1024     1
# [ 23]             CountMin    [0, 1, 2, 3, 4]     4     1    20     3   4096     1
# [ 25]                 Kary    [0, 1, 2, 3, 4]     5     1    20     3   4096     1
#           ---------------------------------------------------------------------------
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  3]              Entropy                [3]     3     1    20     3   2048     1
# [  6]                 Kary                [3]     5     1    20     3   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  8]              Entropy             [0, 2]     3     1    10     3   2048     1
# [ 10]             CountMin             [0, 2]     4     1    10     3   4096     1
# [ 11]                 Kary             [0, 2]     5     1    10     3   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#           ---------------------------------------------------------------------------
# [ 15]              Entropy       [0, 1, 2, 3]     3     1    20     3   2048     1
# [ 18]                 Kary       [0, 1, 2, 3]     5     1    20     3   1024     1
#           ---------------------------------------------------------------------------
# overall     269.062500
# salu        156.250000
# hashcall    104.166667
# sram          8.645833
# dtype: float64
# overall     85.937503
# salu        43.750000
# hashcall    37.500000
# sram         4.687500
# dtype: float64
# overall     145.902778
# salu         85.416667
# hashcall     56.944444
# sram          3.541667
# dtype: float64
# overall     22.777778
# hashcall     6.944444
# salu        10.416667
# sram         5.416667
# dtype: float64
# hashcall    72.413793
# overall     73.801355
# salu        77.586207
# sram        17.094016
# dtype: float64

# %%
# looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload3-7", 0)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  1]  CountingBloomFilter                [3]     1     1    20     1   4096     1
# [  2]              Entropy                [3]     3     1    10     2   2048     1
# [  3]                 Kary                [3]     5     1    20     1   4096     1
# [  4]                 Kary                [3]     5     2    20     3   2048     1
# [  5]                 MRAC                [3]     6     2    10     1   1024    16
# [  6]  CountingBloomFilter                [0]     1     1    20     3   4096     1
# [  7]              Entropy                [0]     3     1    20     5   1024     1
# [  8]              Entropy                [0]     3     2    20     5   2048     1
# [  9]             CountMin                [0]     4     1    10     3   1024     1
# [ 10]                 Kary                [0]     5     1    10     4   2048     1
# [ 11]                 Kary                [0]     5     2    10     1   2048     1
# [ 12]                 Kary                [0]     5     2    20     4   2048     1
# [ 13]                 MRAC                [0]     6     1    20     1   1024     4
# [ 14]  CountingBloomFilter             [0, 2]     1     1    20     1   1024     1
# [ 15]              Entropy             [0, 2]     3     1    10     4   1024     1
# [ 16]                 Kary             [0, 2]     5     2    20     4   4096     1
# [ 17]                 MRAC             [0, 2]     6     1    20     1   1024    16
# [ 18]  CountingBloomFilter             [0, 1]     1     1    20     3   1024     1
# [ 19]              Entropy             [0, 1]     3     2    10     4   1024     1
# [ 20]              Entropy             [0, 1]     3     2    20     1   1024     1
# [ 21]             CountMin             [0, 1]     4     2    20     2   1024     1
# [ 22]                 Kary             [0, 1]     5     1    10     4   4096     1
# [ 23]                 Kary             [0, 1]     5     1    20     1   2048     1
# [ 24]                 Kary             [0, 1]     5     2    10     3   4096     1
# [ 25]                 MRAC             [0, 1]     6     2    10     1   1024    16
# -------------------------------------------------------------------------------------
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  4]                 Kary                [3]     5     2    20     3   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  2]              Entropy                [3]     3     1    10     2   2048     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [  1]  CountingBloomFilter                [3]     1     1    20     1   4096     1
# [  3]                 Kary                [3]     5     1    20     1   4096     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  5]                 MRAC                [3]     6     2    10     1   1024    16
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  6]  CountingBloomFilter                [0]     1     1    20     3   4096     1
# [  7]              Entropy                [0]     3     1    20     5   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 13]                 MRAC                [0]     6     1    20     1   1024     4
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 15]              Entropy             [0, 2]     3     1    10     4   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 16]                 Kary             [0, 2]     5     2    20     4   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 14]  CountingBloomFilter             [0, 2]     1     1    20     1   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 17]                 MRAC             [0, 2]     6     1    20     1   1024    16
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 18]  CountingBloomFilter             [0, 1]     1     1    20     3   1024     1
# [ 23]                 Kary             [0, 1]     5     1    20     1   2048     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 25]                 MRAC             [0, 1]     6     2    10     1   1024    16
#           ---------------------------------------------------------------------------
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  8]              Entropy                [0]     3     2    20     5   2048     1
# [ 12]                 Kary                [0]     5     2    20     4   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  9]             CountMin                [0]     4     1    10     3   1024     1
# [ 10]                 Kary                [0]     5     1    10     4   2048     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 11]                 Kary                [0]     5     2    10     1   2048     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 19]              Entropy             [0, 1]     3     2    10     4   1024     1
# [ 24]                 Kary             [0, 1]     5     2    10     3   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 22]                 Kary             [0, 1]     5     1    10     4   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#           ---------------------------------------------------------------------------
# [ 20]              Entropy             [0, 1]     3     2    20     1   1024     1
# [ 21]             CountMin             [0, 1]     4     2    20     2   1024     1
#           ---------------------------------------------------------------------------
# overall     233.888889
# salu        131.250000
# hashcall     93.055556
# sram          9.583333
# dtype: float64
# overall     140.520844
# salu         66.666667
# hashcall     62.500000
# sram         11.354167
# dtype: float64
# overall     57.222222
# salu        33.333333
# hashcall    22.222222
# sram         1.666667
# dtype: float64
# overall     16.388889
# hashcall     5.555556
# salu         8.333333
# sram         2.500000
# dtype: float64
# hashcall    40.963855
# overall     46.099710
# salu        54.430379
# sram       -23.148146
# dtype: float64

# %%
# looks infeasible -> reduce it to 18 sketches?
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload2-3", 2)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  1]             CountMin                [1]     4     1    20     5   4096     1
# [  2]          CountSketch                [1]     4     1    30     1   4096     1
# [  3]                 Kary                [1]     5     1    10     2   1024     1
# [  4]                 Kary                [1]     5     1    20     5   4096     1
# [  5]              UnivMon                [1]     7     1    10     1   2048    16
# [  6]             CountMin             [0, 2]     4     1    20     1   4096     1
# [  7]                 Kary             [0, 2]     5     1    10     2   1024     1
# [  8]                 Kary             [0, 2]     5     1    20     5   2048     1
# [  9]              UnivMon             [0, 2]     7     1    10     1   1024    16
# [ 10]              UnivMon             [0, 2]     7     1    30     1   1024    16
# [ 11]             CountMin             [0, 1]     4     1    20     3   2048     1
# [ 12]             CountMin             [0, 1]     4     1    30     4   1024     1
# [ 13]                 Kary             [0, 1]     5     1    10     3   4096     1
# [ 14]                 Kary             [0, 1]     5     1    20     1   2048     1
# [ 15]                 Kary             [0, 1]     5     1    30     4   2048     1
# [ 16]              UnivMon             [0, 1]     7     1    10     4   1024    16
# [ 17]          CountSketch       [0, 1, 2, 3]     4     1    20     3   4096     1
# [ 18]                 Kary       [0, 1, 2, 3]     5     1    10     1   4096     1
# [ 19]                 Kary       [0, 1, 2, 3]     5     1    30     1   4096     1
# [ 20]              UnivMon       [0, 1, 2, 3]     7     1    10     1   2048    16
# [ 21]              UnivMon       [0, 1, 2, 3]     7     1    30     5   1024    16
# [ 22]                 Kary    [0, 1, 2, 3, 4]     5     1    10     4   4096     1
# [ 23]                 Kary    [0, 1, 2, 3, 4]     5     1    20     3   1024     1
# [ 24]              UnivMon    [0, 1, 2, 3, 4]     7     1    10     5   2048    16
# [ 25]              UnivMon    [0, 1, 2, 3, 4]     7     1    30     5   2048    16
# -------------------------------------------------------------------------------------
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  1]             CountMin                [1]     4     1    20     5   4096     1
# [  4]                 Kary                [1]     5     1    20     5   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  3]                 Kary                [1]     5     1    10     2   1024     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  7]                 Kary             [0, 2]     5     1    10     2   1024     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 18]                 Kary       [0, 1, 2, 3]     5     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 16]              UnivMon             [0, 1]     7     1    10     4   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  2]          CountSketch                [1]     4     1    30     1   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  5]              UnivMon                [1]     7     1    10     1   2048    16
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 20]              UnivMon       [0, 1, 2, 3]     7     1    10     1   2048    16
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  6]             CountMin             [0, 2]     4     1    20     1   4096     1
# [  8]                 Kary             [0, 2]     5     1    20     5   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 12]             CountMin             [0, 1]     4     1    30     4   1024     1
# [ 15]                 Kary             [0, 1]     5     1    30     4   2048     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 19]                 Kary       [0, 1, 2, 3]     5     1    30     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 21]              UnivMon       [0, 1, 2, 3]     7     1    30     5   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  9]              UnivMon             [0, 2]     7     1    10     1   1024    16
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 10]              UnivMon             [0, 2]     7     1    30     1   1024    16
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 17]          CountSketch       [0, 1, 2, 3]     4     1    20     3   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 11]             CountMin             [0, 1]     4     1    20     3   2048     1
# [ 14]                 Kary             [0, 1]     5     1    20     1   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 13]                 Kary             [0, 1]     5     1    10     3   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 24]              UnivMon    [0, 1, 2, 3, 4]     7     1    10     5   2048    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 25]              UnivMon    [0, 1, 2, 3, 4]     7     1    30     5   2048    16
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 22]                 Kary    [0, 1, 2, 3, 4]     5     1    10     4   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 23]                 Kary    [0, 1, 2, 3, 4]     5     1    20     3   1024     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
# overall     314.618056
# salu        147.916667
# hashcall    130.555556
# sram         36.145833
# dtype: float64
# overall     234.201422
# salu         64.583333
# hashcall    101.388889
# sram         68.229167
# dtype: float64
# overall     238.680556
# salu        139.583333
# hashcall     93.055556
# sram          6.041667
# dtype: float64
# overall     28.194444
# hashcall     6.944444
# salu        10.416667
# sram        10.833333
# dtype: float64
# hashcall    51.552795
# overall     52.576084
# salu        73.913043
# sram       -87.407405
# dtype: float64

# %%
# looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload1-3", 0)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  1]          BloomFilter                [3]     1     1    10     2 131072     1
# [  2]       LinearCounting                [3]     2     1    10     1   4096     1
# [  3]              Entropy                [3]     3     1    10     1   4096     1
# [  4]              Entropy                [3]     3     1    20     5   1024     1
# [  5]                 MRAC                [3]     6     1    10     1   1024    16
# [  6]                 MRAC                [3]     6     1    20     1   2048    16
# [  7]  CountingBloomFilter             [1, 3]     1     1    20     5   1024     1
# [  8]              Entropy             [1, 3]     3     1    10     2   4096     1
# [  9]              Entropy             [1, 3]     3     1    20     5   1024     1
# [ 10]                 MRAC             [1, 3]     6     1    10     1   2048    16
# [ 11]                 MRAC             [1, 3]     6     1    20     1   1024     4
# [ 12]          BloomFilter                [0]     1     1    10     2  32768     1
# [ 13]  CountingBloomFilter                [0]     1     1    20     3   2048     1
# [ 14]       LinearCounting                [0]     2     1    10     1  32768     1
# [ 15]                  MRB                [0]     2     1    20     1   1024    16
# [ 16]              Entropy                [0]     3     1    10     4   1024     1
# [ 17]              Entropy                [0]     3     1    20     2   1024     1
# [ 18]                 MRAC                [0]     6     1    10     1   2048     4
# [ 19]                 MRAC                [0]     6     1    20     1   2048    16
# [ 20]          BloomFilter    [0, 1, 2, 3, 4]     1     1    20     4   4096     1
# [ 21]                  MRB    [0, 1, 2, 3, 4]     2     1    10     1   1024    16
# [ 22]       LinearCounting    [0, 1, 2, 3, 4]     2     1    20     1  65536     1
# [ 23]              Entropy    [0, 1, 2, 3, 4]     3     1    10     4   1024     1
# [ 24]              Entropy    [0, 1, 2, 3, 4]     3     1    20     2   2048     1
# [ 25]                 MRAC    [0, 1, 2, 3, 4]     6     1    10     1   1024    16
# -------------------------------------------------------------------------------------
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  4]              Entropy                [3]     3     1    20     5   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  1]          BloomFilter                [3]     1     1    10     2 131072     1
# [  2]       LinearCounting                [3]     2     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  3]              Entropy                [3]     3     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 16]              Entropy                [0]     3     1    10     4   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 13]  CountingBloomFilter                [0]     1     1    20     3   2048     1
# [ 17]              Entropy                [0]     3     1    20     2   1024     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 12]          BloomFilter                [0]     1     1    10     2  32768     1
# [ 14]       LinearCounting                [0]     2     1    10     1  32768     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 20]          BloomFilter    [0, 1, 2, 3, 4]     1     1    20     4   4096     1
# [ 22]       LinearCounting    [0, 1, 2, 3, 4]     2     1    20     1  65536     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 23]              Entropy    [0, 1, 2, 3, 4]     3     1    10     4   1024     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  5]                 MRAC                [3]     6     1    10     1   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  6]                 MRAC                [3]     6     1    20     1   2048    16
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  7]  CountingBloomFilter             [1, 3]     1     1    20     5   1024     1
# [  9]              Entropy             [1, 3]     3     1    20     5   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  8]              Entropy             [1, 3]     3     1    10     2   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 10]                 MRAC             [1, 3]     6     1    10     1   2048    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 11]                 MRAC             [1, 3]     6     1    20     1   1024     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 18]                 MRAC                [0]     6     1    10     1   2048     4
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 19]                 MRAC                [0]     6     1    20     1   2048    16
# [ 15]                  MRB                [0]     2     1    20     1   1024    16
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 25]                 MRAC    [0, 1, 2, 3, 4]     6     1    10     1   1024    16
# [ 21]                  MRB    [0, 1, 2, 3, 4]     2     1    10     1   1024    16
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 24]              Entropy    [0, 1, 2, 3, 4]     3     1    20     2   2048     1
#           ---------------------------------------------------------------------------
# overall     230.798611
# salu        110.416667
# hashcall     86.111111
# sram         34.270833
# dtype: float64
# overall     147.083348
# salu         54.166667
# hashcall     41.666667
# sram         51.250000
# dtype: float64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     36.271996
# salu        50.943396
# hashcall    51.612903
# sram       -49.544072
# dtype: float64

# %%
# looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload1-1", 2)
# Out:
# overall     219.965278
# salu         95.833333
# hashcall     77.777778
# sram         46.354167
# dtype: float64
# overall     189.444457
# salu         64.583333
# hashcall     56.944444
# sram         67.916667
# dtype: float64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     13.875290
# salu        32.608695
# hashcall    26.785714
# sram       -46.516853
# dtype: float64
