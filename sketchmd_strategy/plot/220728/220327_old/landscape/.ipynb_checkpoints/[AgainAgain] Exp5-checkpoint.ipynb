# %%
import plot.plot_common as pc
import importlib
importlib.reload(pc)

out = "../../workload_manage/landscape/output"
filename = "landscape3.pkl"

output_dict = pc.data_read(out, filename)
# Out:
# [load output]
# [success]

# %%
candidate_list = [output_dict["gd"]["bf"]["bf"], output_dict["o5"]]
name_list = ["gd_bf_bf", "o5"]

# %%
# [11] avg(73%) / 74% reduction, looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload3-10")
# Out:
# avg performance: 72.76366472957488
# median performance: 72.45435026563376
# 24
# 72.47074969324213
# overall     90.555556
# salu        52.083333
# hashcall    34.722222
# sram         3.750000
# dtype: float64
# overall     29.166667
# salu        14.583333
# hashcall    12.500000
# sram         2.083333
# dtype: float64
# overall     60.798611
# salu        35.416667
# hashcall    23.611111
# sram         1.770833
# dtype: float64
# overall     12.500000
# hashcall     4.166667
# salu         6.250000
# sram         2.083333
# dtype: float64
# hashcall    71.428570
# overall     72.470750
# salu        76.190475
# sram        24.528297
# dtype: float64
#
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]  CountingBloomFilter                [3]     1     1    10     1   2048     1
# [  0]              Entropy                [3]     3     1    10     1   2048     1
# [  0]              Entropy                [3]     3     1    20     1   4096     1
# [  0]             CountMin                [3]     4     1    10     1   2048     1
# [  0]             CountMin                [3]     4     1    20     1   4096     1
# [  0]                 Kary                [3]     5     1    10     1   4096     1
# [  0]                 Kary                [3]     5     1    20     1   4096     1
# [  0]  CountingBloomFilter             [1, 3]     1     1    10     1   2048     1
# [  0]  CountingBloomFilter             [1, 3]     1     1    20     1   1024     1
# [  0]              Entropy             [1, 3]     3     1    10     1   1024     1
# [  0]              Entropy             [1, 3]     3     1    20     1   1024     1
# [  0]             CountMin             [1, 3]     4     1    10     1   4096     1
# [  0]             CountMin             [1, 3]     4     1    20     1   4096     1
# [  0]                 Kary             [1, 3]     5     1    20     1   1024     1
# [  0]  CountingBloomFilter                [0]     1     1    10     1   2048     1
# [  0]              Entropy                [0]     3     1    10     1   4096     1
# [  0]              Entropy                [0]     3     1    20     1   4096     1
# [  0]             CountMin                [0]     4     1    10     1   1024     1
# [  0]             CountMin                [0]     4     1    20     1   1024     1
# [  0]                 Kary                [0]     5     1    10     1   4096     1
# [  0]  CountingBloomFilter             [0, 1]     1     1    10     1   4096     1
# [  0]              Entropy             [0, 1]     3     1    10     1   2048     1
# [  0]              Entropy             [0, 1]     3     1    20     1   1024     1
# [  0]                 Kary             [0, 1]     5     1    10     1   1024     1
# [  0]                 Kary             [0, 1]     5     1    20     1   4096     1
# -------------------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  1]  CountingBloomFilter                [3]     1     1    10     1   2048     1
# [  2]              Entropy                [3]     3     1    10     1   2048     1
# [  4]             CountMin                [3]     4     1    10     1   2048     1
# [  6]                 Kary                [3]     5     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  3]              Entropy                [3]     3     1    20     1   4096     1
# [  5]             CountMin                [3]     4     1    20     1   4096     1
# [  7]                 Kary                [3]     5     1    20     1   4096     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  8]  CountingBloomFilter             [1, 3]     1     1    10     1   2048     1
# [ 10]              Entropy             [1, 3]     3     1    10     1   1024     1
# [ 12]             CountMin             [1, 3]     4     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  9]  CountingBloomFilter             [1, 3]     1     1    20     1   1024     1
# [ 11]              Entropy             [1, 3]     3     1    20     1   1024     1
# [ 13]             CountMin             [1, 3]     4     1    20     1   4096     1
# [ 14]                 Kary             [1, 3]     5     1    20     1   1024     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 15]  CountingBloomFilter                [0]     1     1    10     1   2048     1
# [ 16]              Entropy                [0]     3     1    10     1   4096     1
# [ 18]             CountMin                [0]     4     1    10     1   1024     1
# [ 20]                 Kary                [0]     5     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 17]              Entropy                [0]     3     1    20     1   4096     1
# [ 19]             CountMin                [0]     4     1    20     1   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 23]              Entropy             [0, 1]     3     1    20     1   1024     1
# [ 25]                 Kary             [0, 1]     5     1    20     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#           ---------------------------------------------------------------------------
# [ 21]  CountingBloomFilter             [0, 1]     1     1    10     1   4096     1
# [ 22]              Entropy             [0, 1]     3     1    10     1   2048     1
# [ 24]                 Kary             [0, 1]     5     1    10     1   1024     1
#           ---------------------------------------------------------------------------

# %%
# [8] avg(49%) / 48% reduction, looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload3-7")
# Out:
# [50.72577517 43.43031162 47.72527688 50.17894127 41.51871429 51.8813476
#  43.22113821 37.97516687 44.33177011 53.09820552 53.20826752 50.40510797
#  49.88251914 43.49555033 48.70225315 44.25745554 41.3528731  45.28323318
#  57.19779332 50.53681532 41.15107623 48.299314   44.7283553  47.58835217
#  54.45554471 44.68770583 57.42490538 46.97590814 38.09866577 55.32375872
#  57.14905227 43.7862796  47.7194     49.89847467 42.98201866 44.44443858
#  52.60447762 49.99999727 49.60206227 45.47639756 38.06146386 42.07289358
#  47.8065599  44.24468129 50.60895135 44.58990684 43.94445924 42.81696732
#  55.61130141 45.15564141 49.49058199 52.23508523 46.4032019  50.6662915
#  41.17951765 51.00247463 46.31104506 43.68134519 44.68171556 50.53834116
#  40.37454678 44.73792419 49.95830663 44.82581181 43.40051945 47.08748018
#  49.26291376 55.50323648 46.73681581 50.5910647  40.8020331  52.05815727
#  49.36369356 53.3483875  43.16080951 52.15331846 58.92962068 50.84745342
#  43.53396625 48.61169284 49.5057799  43.09987503 50.52665927 53.0027343
#  43.43870108 45.91919409 45.93554985 39.67596246 47.45911643 49.53768969
#  59.63876056 51.73988373 55.81269179 47.76957514 49.09240791 48.00764925
#  46.24238108 39.68359196 49.13668052 44.89661696]

# %%
# [5] avg(46%) -> this is infeasible, we need to reduce # of sketch instances
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload2-3")
# Out:
# avg performance: 46.49714307178475
# median performance: 46.41218108185751
# 41
# 46.48619211769554
# overall     328.263889
# salu        160.416667
# hashcall    134.722222
# sram         33.125000
# dtype: float64
# overall     255.902809
# salu         77.083333
# hashcall    115.277778
# sram         63.541667
# dtype: float64
# overall     192.5
# salu        112.5
# hashcall     75.0
# sram          5.0
# dtype: float64
# overall     22.777778
# hashcall     6.944444
# salu        10.416667
# sram         5.416667
# dtype: float64
# hashcall    41.721854
# overall     46.486192
# salu        67.938931
# sram       -80.874315
# dtype: float64
#
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  1]             CountMin                [3]     4     1    10     2   2048     1
# [  2]             CountMin                [3]     4     1    30     5   4096     1
# [  3]                 Kary                [3]     5     1    10     5   1024     1
# [  4]                 Kary                [3]     5     1    20     3   4096     1
# [  5]                 Kary                [3]     5     1    30     1   2048     1
# [  6]              UnivMon                [3]     7     1    20     2   1024    16
# [  7]             CountMin                [1]     4     1    10     1   2048     1
# [  8]                 Kary                [1]     5     1    10     3   2048     1
# [  9]              UnivMon                [1]     7     1    20     4   1024    16
# [ 10]              UnivMon                [1]     7     1    30     4   2048    16
# [ 11]          CountSketch                [0]     4     1    10     3   4096     1
# [ 12]             CountMin                [0]     4     1    20     3   4096     1
# [ 13]          CountSketch                [0]     4     1    30     4   2048     1
# [ 14]                 Kary                [0]     5     1    10     4   4096     1
# [ 15]             CountMin             [0, 2]     4     1    10     1   1024     1
# [ 16]             CountMin             [0, 2]     4     1    20     3   4096     1
# [ 17]          CountSketch             [0, 2]     4     1    30     3   1024     1
# [ 18]                 Kary             [0, 2]     5     1    20     3   4096     1
# [ 19]                 Kary             [0, 2]     5     1    30     1   1024     1
# [ 20]          CountSketch    [0, 1, 2, 3, 4]     4     1    10     2   4096     1
# [ 21]                 Kary    [0, 1, 2, 3, 4]     5     1    10     1   4096     1
# [ 22]                 Kary    [0, 1, 2, 3, 4]     5     1    20     5   4096     1
# [ 23]                 Kary    [0, 1, 2, 3, 4]     5     1    30     4   2048     1
# [ 24]              UnivMon    [0, 1, 2, 3, 4]     7     1    20     5   1024    16
# [ 25]              UnivMon    [0, 1, 2, 3, 4]     7     1    30     5   2048    16
# -------------------------------------------------------------------------------------
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  1]             CountMin                [3]     4     1    10     2   2048     1
# [  3]                 Kary                [3]     5     1    10     5   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  2]             CountMin                [3]     4     1    30     5   4096     1
# [  5]                 Kary                [3]     5     1    30     1   2048     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  4]                 Kary                [3]     5     1    20     3   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  7]             CountMin                [1]     4     1    10     1   2048     1
# [  8]                 Kary                [1]     5     1    10     3   2048     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [  9]              UnivMon                [1]     7     1    20     4   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  6]              UnivMon                [3]     7     1    20     2   1024    16
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 20]          CountSketch    [0, 1, 2, 3, 4]     4     1    10     2   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 10]              UnivMon                [1]     7     1    30     4   2048    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 13]          CountSketch                [0]     4     1    30     4   2048     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 14]                 Kary                [0]     5     1    10     4   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 12]             CountMin                [0]     4     1    20     3   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 15]             CountMin             [0, 2]     4     1    10     1   1024     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 11]          CountSketch                [0]     4     1    10     3   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 17]          CountSketch             [0, 2]     4     1    30     3   1024     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 22]                 Kary    [0, 1, 2, 3, 4]     5     1    20     5   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 16]             CountMin             [0, 2]     4     1    20     3   4096     1
# [ 18]                 Kary             [0, 2]     5     1    20     3   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 19]                 Kary             [0, 2]     5     1    30     1   1024     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 21]                 Kary    [0, 1, 2, 3, 4]     5     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#      ***********************************[O4]****************************************
# [Big]
#           ---------------------------------------------------------------------------
# [ 24]              UnivMon    [0, 1, 2, 3, 4]     7     1    20     5   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 25]              UnivMon    [0, 1, 2, 3, 4]     7     1    30     5   2048    16
#           ---------------------------------------------------------------------------
#
#      ********************************************************************************
#
#           ---------------------------------------------------------------------------
# [ 23]                 Kary    [0, 1, 2, 3, 4]     5     1    30     4   2048     1
#           ---------------------------------------------------------------------------

# %%
# [2] avg(36%) -> 38% This can be feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload1-3", 2)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]          BloomFilter                [1]     1     1    20     4 131072     1
# [  0]                  MRB                [1]     2     1    10     1   1024    16
# [  0]       LinearCounting                [1]     2     1    20     1   4096     1
# [  0]              Entropy                [1]     3     1    10     5   4096     1
# [  0]              Entropy                [1]     3     1    20     4   2048     1
# [  0]                 MRAC                [1]     6     1    10     1   1024     4
# [  0]                 MRAC                [1]     6     1    20     1   1024     4
# [  0]  CountingBloomFilter             [1, 3]     1     1    20     5   4096     1
# [  0]       LinearCounting             [1, 3]     2     1    20     1 131072     1
# [  0]              Entropy             [1, 3]     3     1    10     5   1024     1
# [  0]              Entropy             [1, 3]     3     1    20     5   1024     1
# [  0]                 MRAC             [1, 3]     6     1    10     1   1024    16
# [  0]                 MRAC             [1, 3]     6     1    20     1   2048     4
# [  0]  CountingBloomFilter             [0, 2]     1     1    20     5   2048     1
# [  0]                  MRB             [0, 2]     2     1    10     1   1024    16
# [  0]              Entropy             [0, 2]     3     1    10     5   1024     1
# [  0]                 MRAC             [0, 2]     6     1    10     1   1024    16
# [  0]                 MRAC             [0, 2]     6     1    20     1   2048     4
# [  0]  CountingBloomFilter       [0, 1, 2, 3]     1     1    20     3   4096     1
# [  0]       LinearCounting       [0, 1, 2, 3]     2     1    10     1  65536     1
# [  0]       LinearCounting       [0, 1, 2, 3]     2     1    20     1   2048     1
# [  0]              Entropy       [0, 1, 2, 3]     3     1    10     1   4096     1
# [  0]              Entropy       [0, 1, 2, 3]     3     1    20     5   1024     1
# [  0]                 MRAC       [0, 1, 2, 3]     6     1    10     1   1024    16
# [  0]                 MRAC       [0, 1, 2, 3]     6     1    20     1   2048    16
# -------------------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  1]          BloomFilter                [1]     1     1    20     4 131072     1
# [  3]       LinearCounting                [1]     2     1    20     1   4096     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  4]              Entropy                [1]     3     1    10     5   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  5]              Entropy                [1]     3     1    20     4   2048     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [  2]                  MRB                [1]     2     1    10     1   1024    16
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  6]                 MRAC                [1]     6     1    10     1   1024     4
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  7]                 MRAC                [1]     6     1    20     1   1024     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [  9]       LinearCounting             [1, 3]     2     1    20     1 131072     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  8]  CountingBloomFilter             [1, 3]     1     1    20     5   4096     1
# [ 11]              Entropy             [1, 3]     3     1    20     5   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 10]              Entropy             [1, 3]     3     1    10     5   1024     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 19]  CountingBloomFilter       [0, 1, 2, 3]     1     1    20     3   4096     1
# [ 23]              Entropy       [0, 1, 2, 3]     3     1    20     5   1024     1
# [ 21]       LinearCounting       [0, 1, 2, 3]     2     1    20     1   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 20]       LinearCounting       [0, 1, 2, 3]     2     1    10     1  65536     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 22]              Entropy       [0, 1, 2, 3]     3     1    10     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 12]                 MRAC             [1, 3]     6     1    10     1   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 13]                 MRAC             [1, 3]     6     1    20     1   2048     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 14]  CountingBloomFilter             [0, 2]     1     1    20     5   2048     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 16]              Entropy             [0, 2]     3     1    10     5   1024     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 17]                 MRAC             [0, 2]     6     1    10     1   1024    16
# [ 15]                  MRB             [0, 2]     2     1    10     1   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 18]                 MRAC             [0, 2]     6     1    20     1   2048     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 24]                 MRAC       [0, 1, 2, 3]     6     1    10     1   1024    16
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 25]                 MRAC       [0, 1, 2, 3]     6     1    20     1   2048    16
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
# overall     274.861111
# salu        127.083333
# hashcall     98.611111
# sram         49.166667
# dtype: float64
# overall     168.090298
# salu         62.500000
# hashcall     48.611111
# sram         56.979167
# dtype: float64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     38.845369
# salu        50.819672
# hashcall    50.704225
# sram       -15.889830
# dtype: float64

# %%
# [2] avg(22%) -> 21% This can be feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload1-1", 2)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]       LinearCounting                [3]     2     2    10     1   1024     1
# [  0]                 MRAC                [3]     6     1    20     1   2048     4
# [  0]              Entropy                [1]     3     2    35     2   1024     1
# [  0]                 MRAC                [1]     6     1    35     1   2048     4
# [  0]                 MRAC                [1]     6     2    10     1   2048     4
# [  0]  CountingBloomFilter             [1, 3]     1     2    25     2   1024     1
# [  0]                  HLL             [1, 3]     2     1    25     1   4096     1
# [  0]              Entropy             [1, 3]     3     1     5     1   2048     1
# [  0]                 MRAC             [1, 3]     6     2    35     1   2048     4
# [  0]                  HLL                [0]     2     2    15     1   4096     1
# [  0]              Entropy                [0]     3     2    15     1   4096     1
# [  0]       LinearCounting             [0, 2]     2     1    20     1   4096     1
# [  0]       LinearCounting             [0, 2]     2     2    10     1 131072     1
# [  0]       LinearCounting             [0, 2]     2     2    30     1   1024     1
# [  0]       LinearCounting             [0, 2]     2     2    35     1  65536     1
# [  0]              Entropy             [0, 2]     3     1    35     5   4096     1
# [  0]          BloomFilter             [0, 1]     1     1    25     2  65536     1
# [  0]  CountingBloomFilter             [0, 1]     1     1    30     4   4096     1
# [  0]                 PCSA             [0, 1]     2     2    30     1   4096     1
# [  0]              Entropy             [0, 1]     3     2     5     1   4096     1
# [  0]                 MRAC             [0, 1]     6     1    20     1   2048     4
# [  0]              Entropy       [0, 1, 2, 3]     3     1    15     2   2048     1
# [  0]              Entropy       [0, 1, 2, 3]     3     1    25     3   1024     1
# [  0]          BloomFilter    [0, 1, 2, 3, 4]     1     2    25     3   2048     1
# [  0]                 MRAC    [0, 1, 2, 3, 4]     6     1    15     1   1024    16
# -------------------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  1]       LinearCounting                [3]     2     2    10     1   1024     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 16]              Entropy             [0, 2]     3     1    35     5   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 12]       LinearCounting             [0, 2]     2     1    20     1   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 14]       LinearCounting             [0, 2]     2     2    30     1   1024     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 15]       LinearCounting             [0, 2]     2     2    35     1  65536     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 13]       LinearCounting             [0, 2]     2     2    10     1 131072     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 18]  CountingBloomFilter             [0, 1]     1     1    30     4   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 19]                 PCSA             [0, 1]     2     2    30     1   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [ 20]              Entropy             [0, 1]     3     2     5     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 17]          BloomFilter             [0, 1]     1     1    25     2  65536     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [ 24]          BloomFilter    [0, 1, 2, 3, 4]     1     2    25     3   2048     1
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  2]                 MRAC                [3]     6     1    20     1   2048     4
#           ---------------------------------------------------------------------------
#           ---------------------------------------------------------------------------
# [  3]              Entropy                [1]     3     2    35     2   1024     1
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  4]                 MRAC                [1]     6     1    35     1   2048     4
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  5]                 MRAC                [1]     6     2    10     1   2048     4
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [  6]  CountingBloomFilter             [1, 3]     1     2    25     2   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [  7]                  HLL             [1, 3]     2     1    25     1   4096     1
#           ---------------------------------------------------------------------------
#
#           ---------------------------------------------------------------------------
# [  8]              Entropy             [1, 3]     3     1     5     1   2048     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [  9]                 MRAC             [1, 3]     6     2    35     1   2048     4
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 10]                  HLL                [0]     2     2    15     1   4096     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 11]              Entropy                [0]     3     2    15     1   4096     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 21]                 MRAC             [0, 1]     6     1    20     1   2048     4
#           ---------------------------------------------------------------------------
#      ===================================[O3]=========================================
# [Big]
#           ---------------------------------------------------------------------------
# [ 23]              Entropy       [0, 1, 2, 3]     3     1    25     3   1024     1
#           ---------------------------------------------------------------------------
# [Small]
#           ---------------------------------------------------------------------------
# [ 22]              Entropy       [0, 1, 2, 3]     3     1    15     2   2048     1
#           ---------------------------------------------------------------------------
#
#      ================================================================================
#
#           ---------------------------------------------------------------------------
# [ 25]                 MRAC    [0, 1, 2, 3, 4]     6     1    15     1   1024    16
#           ---------------------------------------------------------------------------
# overall     171.180556
# salu         83.333333
# hashcall     63.888889
# sram         23.958333
# dtype: float64
# overall     135.138900
# salu         60.416667
# hashcall     47.222222
# sram         27.500000
# dtype: float64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     0
# salu        0
# hashcall    0
# sram        0
# dtype: int64
# overall     21.054760
# salu        27.500000
# hashcall    26.086956
# sram       -14.782608
# dtype: float64
