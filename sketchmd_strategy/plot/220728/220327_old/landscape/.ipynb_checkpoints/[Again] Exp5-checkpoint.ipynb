# %%
import plot.plot_common as pc
import importlib
importlib.reload(pc)

out = "../../workload_manage/landscape/output"
filename = "landscape2.pkl"

output_dict = pc.data_read(out, filename)
# Out:
# [load output]
# [success]

# %%
candidate_list = [output_dict["gd"]["bf"]["bf"], output_dict["o5"]]
name_list = ["gd_bf_bf", "o5"]

# %%
# [11] avg(73%) / 74% reduction, looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload3-10", 8)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]  CountingBloomFilter                [3]     1     1    10     3   1024     1
# [  0]              Entropy                [3]     3     1    10     3   4096     1
# [  0]              Entropy                [3]     3     1    20     3   2048     1
# [  0]             CountMin                [3]     4     1    10     3   1024     1
# [  0]                 Kary                [3]     5     1    10     3   1024     1
# [  0]                 Kary                [3]     5     1    20     3   2048     1
# [  0]  CountingBloomFilter             [0, 2]     1     1    20     3   2048     1
# [  0]              Entropy             [0, 2]     3     1    10     3   2048     1
# ...

# %%
# [8] avg(49%) / 48% reduction, looks feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload3-7", 3)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]              Entropy                [3]     3     1    10     1   4096     1
# [  0]              Entropy                [3]     3     1    20     2   2048     1
# [  0]              Entropy                [3]     3     2    10     2   2048     1
# [  0]              Entropy                [3]     3     2    20     3   1024     1
# [  0]             CountMin                [3]     4     2    10     2   1024     1
# [  0]             CountMin                [3]     4     2    20     3   2048     1
# [  0]                 Kary                [3]     5     1    10     2   2048     1
# [  0]                 Kary                [3]     5     2    10     3   4096     1
# ...

# %%
# [5] avg(46%) -> this is infeasible, we need to reduce # of sketch instances
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload2-3", 6)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  1]             CountMin                [3]     4     1    10     5   1024     1
# [  2]                 Kary                [3]     5     1    20     1   4096     1
# [  3]                 Kary                [3]     5     1    30     1   2048     1
# [  4]              UnivMon                [3]     7     1    30     4   1024    16
# [  5]                 Kary                [1]     5     1    20     1   2048     1
# [  6]                 Kary                [1]     5     1    30     3   1024     1
# [  7]              UnivMon                [1]     7     1    10     4   1024    16
# [  8]              UnivMon                [1]     7     1    20     3   1024    16
# ...

# %%
# [2] avg(36%) -> 38% This can be feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload1-3", 2)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]          BloomFilter                [1]     1     1    20     4 131072     1
# [  0]                  MRB                [1]     2     1    10     1   1024    16
# [  0]       LinearCounting                [1]     2     1    20     1   4096     1
# [  0]              Entropy                [1]     3     1    10     5   4096     1
# [  0]              Entropy                [1]     3     1    20     4   2048     1
# [  0]                 MRAC                [1]     6     1    10     1   1024     4
# [  0]                 MRAC                [1]     6     1    20     1   1024     4
# [  0]  CountingBloomFilter             [1, 3]     1     1    20     5   4096     1
# ...

# %%
# [2] avg(22%) -> 21% This can be feasible
import plot.plot_common as pc
import importlib
importlib.reload(pc)
pc.data_parse_search(candidate_list, name_list, "workload1-1", 2)
# Out:
# -------------------------------------------------------------------------------------
# [ id]                 NAME                key  stat  size epoch   row  width level
# -------------------------------------------------------------------------------------
# [  0]       LinearCounting                [3]     2     2    10     1   1024     1
# [  0]                 MRAC                [3]     6     1    20     1   2048     4
# [  0]              Entropy                [1]     3     2    35     2   1024     1
# [  0]                 MRAC                [1]     6     1    35     1   2048     4
# [  0]                 MRAC                [1]     6     2    10     1   2048     4
# [  0]  CountingBloomFilter             [1, 3]     1     2    25     2   1024     1
# [  0]                  HLL             [1, 3]     2     1    25     1   4096     1
# [  0]              Entropy             [1, 3]     3     1     5     1   2048     1
# ...
